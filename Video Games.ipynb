# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("data/Video_Games_Sales_as_at_22_Dec_2016.csv")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# 0              76.0          51.0          8       322.0  Nintendo      E
# 1               NaN           NaN        NaN         NaN       NaN    NaN
# 2              82.0          73.0        8.3       709.0  Nintendo      E
# 3              80.0          73.0          8       192.0  Nintendo      E
# 4               NaN           NaN        NaN         NaN       NaN    NaN
# ...             ...           ...        ...         ...       ...    ...
# 16714           NaN           NaN        NaN         NaN       NaN    NaN
# 16715           NaN           NaN        NaN         NaN       NaN    NaN
# 16716           NaN           NaN        NaN         NaN       NaN    NaN
# 16717           NaN           NaN        NaN         NaN       NaN    NaN
# 16718           NaN           NaN        NaN         NaN       NaN    NaN
#
# [16719 rows x 16 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
df.shape
# Out:
# (16719, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# 25%        0.000000      0.060000     60.000000     12.000000     10.000000
# 50%        0.010000      0.170000     71.000000     21.000000     24.000000
# 75%        0.030000      0.470000     79.000000     36.000000     81.000000
# max       10.570000     82.530000     98.000000    113.000000  10665.000000

# %%
numericas= []
for i in df.columns:
    if df[i].dtypes== "float":
        numericas.append(i)

# %%
categoricas= []
for i in df.columns:
    if df[i].dtypes== "object":
        categoricas.append(i)

# %%
print(categoricas, numericas)
# Out:
# ['Name', 'Platform', 'Genre', 'Publisher', 'User_Score', 'Developer', 'Rating'] ['Year_of_Release', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score', 'Critic_Count', 'User_Count']

# %%
history= df.sort_values(by=['Year_of_Release'])
history.head(15)
# Out:
#                       Name Platform  Year_of_Release     Genre  \
# 262              Asteroids     2600           1980.0   Shooter
# 5360               Freeway     2600           1980.0    Action
# 546        Missile Command     2600           1980.0   Shooter
# 2650                Boxing     2600           1980.0  Fighting
# 4019            Ice Hockey     2600           1980.0    Sports
# 6301                Bridge     2600           1980.0      Misc
# 1764               Kaboom!     2600           1980.0      Misc
# 6876              Checkers     2600           1980.0      Misc
# 1968              Defender     2600           1980.0      Misc
# 4123            Grand Prix     2600           1981.0    Racing
# 5997             Fast Food     2600           1981.0    Action
# 240               Pitfall!     2600           1981.0  Platform
# 7881  International Soccer     2600           1981.0    Sports
# 8459          Armor Ambush     2600           1981.0    Action
# 2645              Air Raid     2600           1981.0    Action
#
#                Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 262                Atari      4.00      0.26       0.0         0.05
# 5360          Activision      0.32      0.02       0.0         0.00
# 546                Atari      2.56      0.17       0.0         0.03
# 2650          Activision      0.72      0.04       0.0         0.01
# 4019          Activision      0.46      0.03       0.0         0.01
# 6301          Activision      0.25      0.02       0.0         0.00
# 1764          Activision      1.07      0.07       0.0         0.01
# 6876               Atari      0.22      0.01       0.0         0.00
# 1968               Atari      0.99      0.05       0.0         0.01
# 4123          Activision      0.45      0.03       0.0         0.00
# 5997             Unknown      0.27      0.02       0.0         0.00
# 240           Activision      4.21      0.24       0.0         0.05
# 7881  Mattel Interactive      0.18      0.01       0.0         0.00
# 8459  Mattel Interactive      0.15      0.01       0.0         0.00
# 2645        Men-A-Vision      0.72      0.04       0.0         0.01
#
#       Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 262           4.31           NaN           NaN        NaN         NaN
# 5360          0.34           NaN           NaN        NaN         NaN
# 546           2.76           NaN           NaN        NaN         NaN
# 2650          0.77           NaN           NaN        NaN         NaN
# 4019          0.49           NaN           NaN        NaN         NaN
# 6301          0.27           NaN           NaN        NaN         NaN
# 1764          1.15           NaN           NaN        NaN         NaN
# 6876          0.24           NaN           NaN        NaN         NaN
# 1968          1.05           NaN           NaN        NaN         NaN
# 4123          0.48           NaN           NaN        NaN         NaN
# 5997          0.29           NaN           NaN        NaN         NaN
# 240           4.50           NaN           NaN        NaN         NaN
# 7881          0.19           NaN           NaN        NaN         NaN
# 8459          0.17           NaN           NaN        NaN         NaN
# 2645          0.77           NaN           NaN        NaN         NaN
#
#      Developer Rating
# 262        NaN    NaN
# 5360       NaN    NaN
# 546        NaN    NaN
# 2650       NaN    NaN
# 4019       NaN    NaN
# 6301       NaN    NaN
# 1764       NaN    NaN
# 6876       NaN    NaN
# 1968       NaN    NaN
# 4123       NaN    NaN
# 5997       NaN    NaN
# 240        NaN    NaN
# 7881       NaN    NaN
# 8459       NaN    NaN
# 2645       NaN    NaN

# %%
news= history.loc[lambda df: df['Year_of_Release'] >= 2015]

# %%
news.head(15)
# Out:
#                                                     Name Platform  \
# 13006                WRC 5: FIA World Rally Championship      PS4
# 15998                       Harukanaru Toki no Naka de 6      PSP
# 3748                                     LEGO Dimensions     WiiU
# 16003      Saenai Kanojo no Sodatekata: Blessing Flowers      PSV
# 12329                                      Darksiders II     XOne
# 105                                            Fallout 4      PS4
# 7172                                                Ride      PS4
# 2954                               Need for Speed (2015)     XOne
# 6323                               Rory McIlroy PGA Tour     XOne
# 14335                                           Rugby 15      PSV
# 12334               Mario vs. Donkey Kong: Tipping Stars      3DS
# 15862                Broken Sword 5: The Serpent's Curse     XOne
# 14982                          Legend of Kay Anniversary      PS4
# 14887  God Eater Off Shot: Lindow-hen Twin Pack & Ani...      PS4
# 13010                                            F1 2015       PC
#
#        Year_of_Release         Genre                               Publisher  \
# 13006           2015.0        Sports                      Bigben Interactive
# 15998           2015.0        Action                              Tecmo Koei
# 3748            2015.0        Action  Warner Bros. Interactive Entertainment
# 16003           2015.0        Action                                     5pb
# 12329           2015.0        Action                            Nordic Games
# 105             2015.0  Role-Playing                      Bethesda Softworks
# 7172            2015.0        Racing                        Milestone S.r.l.
# 2954            2015.0        Racing                         Electronic Arts
# 6323            2015.0        Action                         Electronic Arts
# 14335           2015.0        Sports                      Bigben Interactive
# 12334           2015.0        Puzzle                                Nintendo
# 15862           2015.0     Adventure                     Revolution Software
# 14982           2015.0        Action                            Nordic Games
# 14887           2015.0          Misc                      Namco Bandai Games
# 13010           2015.0        Racing                             Codemasters
#
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 13006      0.00      0.05      0.00         0.01          0.05           NaN
# 15998      0.00      0.00      0.02         0.00          0.02           NaN
# 3748       0.30      0.18      0.00         0.05          0.53          62.0
# 16003      0.00      0.00      0.02         0.00          0.02           NaN
# 12329      0.04      0.02      0.00         0.01          0.06           NaN
# 105        2.53      3.27      0.24         1.13          7.16          87.0
# 7172       0.04      0.13      0.03         0.03          0.22          66.0
# 2954       0.30      0.33      0.00         0.06          0.69           NaN
# 6323       0.16      0.09      0.00         0.02          0.27          60.0
# 14335      0.00      0.03      0.00         0.01          0.03           NaN
# 12334      0.00      0.00      0.06         0.00          0.06          70.0
# 15862      0.00      0.02      0.00         0.00          0.02          77.0
# 14982      0.00      0.02      0.00         0.00          0.03          62.0
# 14887      0.00      0.00      0.03         0.00          0.03           NaN
# 13010      0.00      0.05      0.00         0.00          0.05          61.0
#
#        Critic_Count User_Score  User_Count  \
# 13006           NaN        NaN         NaN
# 15998           NaN        NaN         NaN
# 3748            5.0        6.5        29.0
# 16003           NaN        NaN         NaN
# 12329           NaN        NaN         NaN
# 105            58.0        6.5      4228.0
# 7172           30.0          7        47.0
# 2954            NaN        NaN         NaN
# 6323           26.0        4.3        77.0
# 14335           NaN        tbd         NaN
# 12334          15.0        7.5        48.0
# 15862          12.0        7.2        11.0
# 14982          22.0        6.4        11.0
# 14887           NaN        NaN         NaN
# 13010          13.0        3.6        63.0
#
#                                     Developer Rating
# 13006                                     NaN    NaN
# 15998                                     NaN    NaN
# 3748                        Traveller's Tales   E10+
# 16003                                     NaN    NaN
# 12329                                     NaN    NaN
# 105                     Bethesda Game Studios      M
# 7172                          Milestone S.r.l      E
# 2954                                      NaN    NaN
# 6323                               EA Tiburon      E
# 14335                   HB Studios Multimedia      E
# 12334  Nintendo, Nintendo Software Technology      E
# 15862                     Revolution Software      T
# 14982                     Neon Studios, Kaiko   E10+
# 14887                                     NaN    NaN
# 13010                             Codemasters      E

# %%
news.tail(20)
# Out:
#                                                     Name Platform  \
# 13228                       Hatsune Miku: Project Diva X      PS4
# 13225                                Ghostbusters (2016)     XOne
# 4033                Plants vs. Zombies: Garden Warfare 2      PS4
# 13215                    Metroid Prime: Federation Force      3DS
# 10528                            The Sims 4: City Living       PC
# 16718                                Winning Post 8 2016      PSV
# 15736                        Prototype: Biohazard Bundle      PS4
# 6086   Dragon Quest Heroes II: Twin Kings and the Pro...      PS4
# 15750            Revolution: 25th Anniversary Collection       PC
# 13116                               R.B.I. Baseball 2016     XOne
# 13111                   Utawarerumono: Futari no Hakuoro      PS4
# 15784                       Taishou Moebius Line Vitable      PSV
# 15792                                   This War of Mine      PS4
# 10726                                      EVE: Valkyrie      PS4
# 15816                                       Koihime Enbu      PS4
# 2204                             Rise of the Tomb Raider      PS4
# 16222   Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 14086   Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16385                   Brothers Conflict: Precious Baby      PSV
# 5936                              Imagine: Makeup Artist       DS
#
#        Year_of_Release         Genre        Publisher  NA_Sales  EU_Sales  \
# 13228           2016.0          Misc             Sega      0.02      0.00
# 13225           2016.0        Action       Activision      0.04      0.00
# 4033            2016.0       Shooter  Electronic Arts      0.20      0.21
# 13215           2016.0        Action         Nintendo      0.02      0.01
# 10528           2016.0    Simulation  Electronic Arts      0.02      0.08
# 16718           2016.0    Simulation       Tecmo Koei      0.00      0.00
# 15736           2016.0        Action       Activision      0.01      0.00
# 6086            2016.0        Action      Square Enix      0.00      0.00
# 15750           2016.0     Adventure       Koch Media      0.00      0.02
# 13116           2016.0        Sports          MLB.com      0.05      0.00
# 13111           2016.0          Misc        Aqua Plus      0.00      0.00
# 15784           2016.0     Adventure  dramatic create      0.00      0.00
# 15792           2016.0        Action      Deep Silver      0.00      0.01
# 10726           2016.0       Shooter              CCP      0.03      0.05
# 15816           2016.0      Fighting             Yeti      0.00      0.00
# 2204            2016.0     Adventure      Square Enix      0.23      0.53
# 16222           2017.0  Role-Playing             Sega      0.00      0.00
# 14086           2017.0  Role-Playing             Sega      0.00      0.00
# 16385           2017.0        Action     Idea Factory      0.00      0.00
# 5936            2020.0    Simulation          Ubisoft      0.27      0.00
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 13228      0.02         0.00          0.05          78.0          22.0
# 13225      0.00         0.01          0.05           NaN           NaN
# 4033       0.00         0.08          0.49          81.0          29.0
# 13215      0.01         0.00          0.05          64.0          56.0
# 10528      0.00         0.01          0.10          77.0          10.0
# 16718      0.01         0.00          0.01           NaN           NaN
# 15736      0.00         0.00          0.02          48.0           4.0
# 6086       0.28         0.00          0.28           NaN           NaN
# 15750      0.00         0.00          0.02           NaN           NaN
# 13116      0.00         0.01          0.05           NaN           NaN
# 13111      0.05         0.00          0.05           NaN           NaN
# 15784      0.02         0.00          0.02           NaN           NaN
# 15792      0.00         0.00          0.02           NaN           NaN
# 10726      0.00         0.02          0.10          73.0          26.0
# 15816      0.02         0.00          0.02           NaN           NaN
# 2204       0.04         0.14          0.94           NaN           NaN
# 16222      0.01         0.00          0.01           NaN           NaN
# 14086      0.04         0.00          0.04           NaN           NaN
# 16385      0.01         0.00          0.01           NaN           NaN
# 5936       0.00         0.02          0.29           NaN           NaN
#
#       User_Score  User_Count                   Developer Rating
# 13228        7.4        41.0                        Sega      T
# 13225        NaN         NaN                         NaN    NaN
# 4033         7.7       111.0                      PopCap   E10+
# 13215        5.1       219.0  Next Level Games, Nintendo      T
# 10528        5.7        30.0                       Maxis      T
# 16718        NaN         NaN                         NaN    NaN
# 15736          2        53.0       Radical Entertainment      M
# 6086         NaN         NaN                         NaN    NaN
# 15750        tbd         NaN         Revolution Software    NaN
# 13116        NaN         NaN                         NaN    NaN
# 13111        NaN         NaN                         NaN    NaN
# 15784        NaN         NaN                         NaN    NaN
# 15792        NaN         NaN                         NaN    NaN
# 10726        6.3        37.0                         CCP      T
# 15816        NaN         NaN                         NaN    NaN
# 2204         NaN         NaN                         NaN    NaN
# 16222        NaN         NaN                         NaN    NaN
# 14086        NaN         NaN                         NaN    NaN
# 16385        NaN         NaN                         NaN    NaN
# 5936         tbd         NaN                     Ubisoft      E

# %% [markdown]
# ### Primero hablemos de los nullos.

# %%
# Veamos cuantos nulls hay en las distintas variables
import missingno as msno
# %matplotlib inline
msno.matrix(df.sample(250))
# Out:
# <AxesSubplot:>

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %% [raw]
# Vemos que en todo lo que son las variables de los críticos hay muchos blancos. De hecho hasta casi la mitad de las muestras!

# %%
# Primero actuemos sobre los que faltan de YEAR. Descartemoslos.  
df= df.dropna(subset=["Year_of_Release"])

# %%
# Actualizamos el cuadro de arriba y ahora quedaron algunos blancos en Name, en Genre y en Publisher. Eliminemos el de Name ya que es un juego sin nombre...
df= df.dropna(subset= ["Name"])

# %%
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# 0              76.0          51.0          8       322.0  Nintendo      E
# 1               NaN           NaN        NaN         NaN       NaN    NaN
# 2              82.0          73.0        8.3       709.0  Nintendo      E
# 3              80.0          73.0          8       192.0  Nintendo      E
# 4               NaN           NaN        NaN         NaN       NaN    NaN
# ...             ...           ...        ...         ...       ...    ...
# 16714           NaN           NaN        NaN         NaN       NaN    NaN
# 16715           NaN           NaN        NaN         NaN       NaN    NaN
# 16716           NaN           NaN        NaN         NaN       NaN    NaN
# 16717           NaN           NaN        NaN         NaN       NaN    NaN
# 16718           NaN           NaN        NaN         NaN       NaN    NaN
#
# [16448 rows x 16 columns]

# %%
# Quiero ver como aparecen los vacíos en las columnas que tienen faltantes
df[["Critic_Count", "Critic_Count", "User_Score", "User_Count", "Developer", "Rating"]].head(40)
# Out:
#     Critic_Count  Critic_Count User_Score  User_Count  \
# 0           51.0          51.0          8       322.0
# 1            NaN           NaN        NaN         NaN
# 2           73.0          73.0        8.3       709.0
# 3           73.0          73.0          8       192.0
# 4            NaN           NaN        NaN         NaN
# 5            NaN           NaN        NaN         NaN
# 6           65.0          65.0        8.5       431.0
# 7           41.0          41.0        6.6       129.0
# 8           80.0          80.0        8.4       594.0
# 9            NaN           NaN        NaN         NaN
# 10           NaN           NaN        NaN         NaN
# 11          64.0          64.0        8.6       464.0
# 12           NaN           NaN        NaN         NaN
# 13          63.0          63.0        7.7       146.0
# 14          45.0          45.0        6.3       106.0
# 15          33.0          33.0        7.4        52.0
# 16          50.0          50.0        8.2      3994.0
# 17          80.0          80.0          9      1588.0
# 18           NaN           NaN        NaN         NaN
# 19          58.0          58.0        7.9        50.0
# 20           NaN           NaN        NaN         NaN
# 21           NaN           NaN        NaN         NaN
# 22           NaN           NaN        NaN         NaN
# 23          58.0          58.0        8.1      3711.0
# 24          62.0          62.0        8.7       730.0
# 25           NaN           NaN        NaN         NaN
# 26          37.0          37.0        7.1        19.0
# 27           NaN           NaN        NaN         NaN
# 28          54.0          54.0        8.4       314.0
# 29          81.0          81.0        3.4      8713.0
# 30           NaN           NaN        NaN         NaN
# 31           NaN           NaN        NaN         NaN
# 32          89.0          89.0        6.3      1454.0
# 33           NaN           NaN        NaN         NaN
# 34          21.0          21.0        5.3       922.0
# 35          73.0          73.0        4.8      2256.0
# 36         100.0         100.0        6.3      2698.0
# 37          39.0          39.0        3.2      5234.0
# 38          56.0          56.0        8.5       664.0
# 39          81.0          81.0        8.9      1662.0
#
#                             Developer Rating
# 0                            Nintendo      E
# 1                                 NaN    NaN
# 2                            Nintendo      E
# 3                            Nintendo      E
# 4                                 NaN    NaN
# 5                                 NaN    NaN
# 6                            Nintendo      E
# 7                            Nintendo      E
# 8                            Nintendo      E
# 9                                 NaN    NaN
# 10                                NaN    NaN
# 11                           Nintendo      E
# 12                                NaN    NaN
# 13                           Nintendo      E
# 14                Good Science Studio      E
# 15                           Nintendo      E
# 16                     Rockstar North      M
# 17                     Rockstar North      M
# 18                                NaN    NaN
# 19                           Nintendo      E
# 20                                NaN    NaN
# 21                                NaN    NaN
# 22                                NaN    NaN
# 23                     Rockstar North      M
# 24                     Rockstar North      M
# 25                                NaN    NaN
# 26                           Nintendo      E
# 27                                NaN    NaN
# 28                  Polyphony Digital      E
# 29  Infinity Ward, Sledgehammer Games      M
# 30                                NaN    NaN
# 31                                NaN    NaN
# 32                           Treyarch      M
# 33                                NaN    NaN
# 34                           Treyarch      M
# 35                           Treyarch      M
# 36                      Infinity Ward      M
# 37  Infinity Ward, Sledgehammer Games      M
# 38                         DMA Design      M
# 39                          Game Arts      T

# %%
history[["Critic_Count", "Critic_Count", "User_Score", "User_Count", "Developer", "Rating"]].head(40)
# Out:
#       Critic_Count  Critic_Count User_Score  User_Count Developer Rating
# 262            NaN           NaN        NaN         NaN       NaN    NaN
# 5360           NaN           NaN        NaN         NaN       NaN    NaN
# 546            NaN           NaN        NaN         NaN       NaN    NaN
# 2650           NaN           NaN        NaN         NaN       NaN    NaN
# 4019           NaN           NaN        NaN         NaN       NaN    NaN
# 6301           NaN           NaN        NaN         NaN       NaN    NaN
# 1764           NaN           NaN        NaN         NaN       NaN    NaN
# 6876           NaN           NaN        NaN         NaN       NaN    NaN
# 1968           NaN           NaN        NaN         NaN       NaN    NaN
# 4123           NaN           NaN        NaN         NaN       NaN    NaN
# 5997           NaN           NaN        NaN         NaN       NaN    NaN
# 240            NaN           NaN        NaN         NaN       NaN    NaN
# 7881           NaN           NaN        NaN         NaN       NaN    NaN
# 8459           NaN           NaN        NaN         NaN       NaN    NaN
# 2645           NaN           NaN        NaN         NaN       NaN    NaN
# 3394           NaN           NaN        NaN         NaN       NaN    NaN
# 1426           NaN           NaN        NaN         NaN       NaN    NaN
# 5111           NaN           NaN        NaN         NaN       NaN    NaN
# 3398           NaN           NaN        NaN         NaN       NaN    NaN
# 2578           NaN           NaN        NaN         NaN       NaN    NaN
# 4948           NaN           NaN        NaN         NaN       NaN    NaN
# 6923           NaN           NaN        NaN         NaN       NaN    NaN
# 6845           NaN           NaN        NaN         NaN       NaN    NaN
# 9488           NaN           NaN        NaN         NaN       NaN    NaN
# 4499           NaN           NaN        NaN         NaN       NaN    NaN
# 1965           NaN           NaN        NaN         NaN       NaN    NaN
# 1305           NaN           NaN        NaN         NaN       NaN    NaN
# 5233           NaN           NaN        NaN         NaN       NaN    NaN
# 4366           NaN           NaN        NaN         NaN       NaN    NaN
# 2131           NaN           NaN        NaN         NaN       NaN    NaN
# 1850           NaN           NaN        NaN         NaN       NaN    NaN
# 2218           NaN           NaN        NaN         NaN       NaN    NaN
# 4309           NaN           NaN        NaN         NaN       NaN    NaN
# 4892           NaN           NaN        NaN         NaN       NaN    NaN
# 1154           NaN           NaN        NaN         NaN       NaN    NaN
# 1108           NaN           NaN        NaN         NaN       NaN    NaN
# 2516           NaN           NaN        NaN         NaN       NaN    NaN
# 4761           NaN           NaN        NaN         NaN       NaN    NaN
# 2805           NaN           NaN        NaN         NaN       NaN    NaN
# 5803           NaN           NaN        NaN         NaN       NaN    NaN

# %% [markdown]
# We can see there are plenty of rows where all this columns are NaN, mainly to the oldest games!
# Our solution will be to set a threshold, where a column must have at least 11 columns with values, if not, it will drop.
# Let´s create a new dataset in order not to loose our df.

# %%
df.shape
# Out:
# (16448, 16)

# %%
df_con_resena= df.dropna(thresh= 11)
df_con_resena
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 0                         Wii Sports      Wii           2006.0      Sports
# 2                     Mario Kart Wii      Wii           2008.0      Racing
# 3                  Wii Sports Resort      Wii           2009.0      Sports
# 6              New Super Mario Bros.       DS           2006.0    Platform
# 7                           Wii Play      Wii           2006.0        Misc
# ...                              ...      ...              ...         ...
# 16702               Mega Brain Boost       DS           2008.0      Puzzle
# 16706        STORM: Frontline Nation       PC           2011.0    Strategy
# 16708                       Plushees       DS           2008.0  Simulation
# 16709                        15 Days       PC           2009.0   Adventure
# 16710  Men in Black II: Alien Escape       GC           2003.0     Shooter
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                   Nintendo     41.36     28.96      3.77         8.45
# 2                   Nintendo     15.68     12.76      3.79         3.29
# 3                   Nintendo     15.61     10.93      3.28         2.95
# 6                   Nintendo     11.28      9.14      6.50         2.88
# 7                   Nintendo     13.96      9.18      2.93         2.84
# ...                      ...       ...       ...       ...          ...
# 16702  Majesco Entertainment      0.01      0.00      0.00         0.00
# 16706                Unknown      0.00      0.01      0.00         0.00
# 16708              Destineer      0.01      0.00      0.00         0.00
# 16709      DTP Entertainment      0.00      0.01      0.00         0.00
# 16710             Infogrames      0.01      0.00      0.00         0.00
#
#        Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 0             82.53          76.0          51.0          8       322.0
# 2             35.52          82.0          73.0        8.3       709.0
# 3             32.77          80.0          73.0          8       192.0
# 6             29.80          89.0          65.0        8.5       431.0
# 7             28.92          58.0          41.0        6.6       129.0
# ...             ...           ...           ...        ...         ...
# 16702          0.01          48.0          10.0        tbd         NaN
# 16706          0.01          60.0          12.0        7.2        13.0
# 16708          0.01           NaN           NaN        tbd         NaN
# 16709          0.01          63.0           6.0        5.8         8.0
# 16710          0.01           NaN           NaN        tbd         NaN
#
#                 Developer Rating
# 0                Nintendo      E
# 2                Nintendo      E
# 3                Nintendo      E
# 6                Nintendo      E
# 7                Nintendo      E
# ...                   ...    ...
# 16702  Interchannel-Holon      E
# 16706              SimBin   E10+
# 16708      Big John Games      E
# 16709   DTP Entertainment    NaN
# 16710               Atari      T
#
# [9940 rows x 16 columns]

# %%
# ¡ ME quede con 9940 filas ! Veamos el grafico de los nulls denuevo.
msno.bar(df_con_resena)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ahora quiero llenar los ausentes en las críticas, y podemos llenarlo así. A modo diccionario

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Critic Score: suele ser un número entre 0 y 100.
# Critic Count: lo mismo. Cantidad de críticos.
# User Score: 0 a 10. QUE ES TBD?? LIMPIAR
# User Count: infinito. Aplicamos media.
# Developer: Puedo llenar "No developer"
# Rating: VER. Limpiar.

# %%
df_con_resena.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9940 entries, 0 to 16710
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             9940 non-null   object
#  1   Platform         9940 non-null   object
#  2   Year_of_Release  9940 non-null   float64
#  3   Genre            9940 non-null   object
#  4   Publisher        9937 non-null   object
#  5   NA_Sales         9940 non-null   float64
#  6   EU_Sales         9940 non-null   float64
#  7   JP_Sales         9940 non-null   float64
#  8   Other_Sales      9940 non-null   float64
#  9   Global_Sales     9940 non-null   float64
#  10  Critic_Score     7983 non-null   float64
#  11  Critic_Count     7983 non-null   float64
#  12  User_Score       9840 non-null   object
#  13  User_Count       7463 non-null   float64
#  14  Developer        9907 non-null   object
#  15  Rating           9769 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 1.3+ MB

# %%
df_con_resena["Rating"].unique()
# Out:
# array(['E', 'M', 'T', 'E10+', 'K-A', nan, 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Por lo tanto reemplazamos los nulos por RP que es Rating Pending!!!

# %%
df_con_resena["User_Score"].unique()
# Out:
# array(['8', '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4', '8.2',
#        '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2', '8.9',
#        '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3', '7.6',
#        '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', nan, '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# tbd is to be determined! Let´s fill that Na = tbd

# %%
# Lets fill NAs !
values= {"Publisher": "No publisher Identified", 
         "Critic_Score": df_con_resena["Critic_Score"].mean(),
         "Critic_Count": df_con_resena["Critic_Count"].median(),
         "User_Score": "tbd", 
         "User_Count": df_con_resena["User_Count"].median(), 
         "Developer": "no developer", 
         "Rating": "RP"}
df_con_resenaR= df_con_resena.fillna(value= values)
df_con_resenaR
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 0                         Wii Sports      Wii           2006.0      Sports
# 2                     Mario Kart Wii      Wii           2008.0      Racing
# 3                  Wii Sports Resort      Wii           2009.0      Sports
# 6              New Super Mario Bros.       DS           2006.0    Platform
# 7                           Wii Play      Wii           2006.0        Misc
# ...                              ...      ...              ...         ...
# 16702               Mega Brain Boost       DS           2008.0      Puzzle
# 16706        STORM: Frontline Nation       PC           2011.0    Strategy
# 16708                       Plushees       DS           2008.0  Simulation
# 16709                        15 Days       PC           2009.0   Adventure
# 16710  Men in Black II: Alien Escape       GC           2003.0     Shooter
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                   Nintendo     41.36     28.96      3.77         8.45
# 2                   Nintendo     15.68     12.76      3.79         3.29
# 3                   Nintendo     15.61     10.93      3.28         2.95
# 6                   Nintendo     11.28      9.14      6.50         2.88
# 7                   Nintendo     13.96      9.18      2.93         2.84
# ...                      ...       ...       ...       ...          ...
# 16702  Majesco Entertainment      0.01      0.00      0.00         0.00
# 16706                Unknown      0.00      0.01      0.00         0.00
# 16708              Destineer      0.01      0.00      0.00         0.00
# 16709      DTP Entertainment      0.00      0.01      0.00         0.00
# 16710             Infogrames      0.01      0.00      0.00         0.00
#
#        Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 0             82.53     76.000000          51.0          8       322.0
# 2             35.52     82.000000          73.0        8.3       709.0
# 3             32.77     80.000000          73.0          8       192.0
# 6             29.80     89.000000          65.0        8.5       431.0
# 7             28.92     58.000000          41.0        6.6       129.0
# ...             ...           ...           ...        ...         ...
# 16702          0.01     48.000000          10.0        tbd        24.0
# 16706          0.01     60.000000          12.0        7.2        13.0
# 16708          0.01     68.994363          22.0        tbd        24.0
# 16709          0.01     63.000000           6.0        5.8         8.0
# 16710          0.01     68.994363          22.0        tbd        24.0
#
#                 Developer Rating
# 0                Nintendo      E
# 2                Nintendo      E
# 3                Nintendo      E
# 6                Nintendo      E
# 7                Nintendo      E
# ...                   ...    ...
# 16702  Interchannel-Holon      E
# 16706              SimBin   E10+
# 16708      Big John Games      E
# 16709   DTP Entertainment     RP
# 16710               Atari      T
#
# [9940 rows x 16 columns]

# %%
if df_con_resenaR["User_Score"]== "tbd":
    pd.count()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-98374e33e171> in <module>
# ----> 1 if df_con_resenaR["User_Score"]== "tbd":
#       2     pd.count()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Veamos como quedan los blancs para este nuevo dataFrame rellenado (de ahí la R del final del nombre)
msno.bar(df_con_resenaR)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Perfecto!!! Todo lleno

# %%
categoricas
# Out:
# ['Name', 'Platform', 'Genre', 'Publisher', 'User_Score', 'Developer', 'Rating']

# %%
for i in categoricas:
    print(df[i].unique())
# Out:
# ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' ...
#  'Woody Woodpecker in Crazy Castle 5' 'LMA Manager 2007'
#  'Haitaka no Psychedelica']
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'WiiU' 'GC' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy']
# ['Nintendo' 'Microsoft Game Studios' 'Take-Two Interactive'
#  'Sony Computer Entertainment' 'Activision' 'Ubisoft' 'Bethesda Softworks'
#  'Electronic Arts' 'Sega' 'SquareSoft' 'Atari' '505 Games' 'Capcom'
#  'GT Interactive' 'Konami Digital Entertainment' 'Square Enix'
#  'Sony Computer Entertainment Europe' 'Virgin Interactive' 'LucasArts'
#  'Warner Bros. Interactive Entertainment' 'Universal Interactive'
#  'Eidos Interactive' 'RedOctane' 'Vivendi Games' 'Enix Corporation'
#  'Namco Bandai Games' 'Palcom' 'Hasbro Interactive' 'THQ'
#  'Fox Interactive' 'Acclaim Entertainment' 'MTV Games'
#  'Disney Interactive Studios' 'Codemasters' 'Majesco Entertainment'
#  'Red Orb' 'Level 5' 'Arena Entertainment' 'Midway Games' 'JVC'
#  'Deep Silver' 'NCSoft' '989 Studios' 'UEP Systems' 'Parker Bros.' 'Maxis'
#  'Imagic' 'Tecmo Koei' 'ASCII Entertainment' 'Valve Software' 'Mindscape'
#  'Infogrames' 'Unknown' 'Square' 'Valve' 'Banpresto' 'Hello Games'
#  'D3Publisher' 'Activision Value' 'Oxygen Interactive'
#  'Red Storm Entertainment' 'Video System' 'Global Star' 'Gotham Games'
#  'Westwood Studios' 'GungHo' 'Crave Entertainment' 'Hudson Soft' 'Coleco'
#  'Rising Star Games' 'TDK Mediactive' 'ASC Games' 'Accolade' 'Zoo Games'
#  'Sony Online Entertainment' '3DO' 'Natsume' 'RTL' 'Alchemist' nan
#  'Black Label Games' 'SouthPeak Games' 'Focus Home Interactive' 'Ocean'
#  'Zoo Digital Publishing' 'Psygnosis' 'City Interactive'
#  'Empire Interactive' 'Success' 'Compile' 'Russel' 'Atlus' 'Mastertronic'
#  'Slightly Mad Studios' 'Taito' 'Agetec' 'Microprose' 'Play It' 'GSP'
#  'Tomy Corporation' 'Sammy Corporation' 'Koch Media' 'Game Factory'
#  'Titus' 'Marvelous Entertainment' 'Genki' 'Mojang' 'CTO SpA' 'TalonSoft'
#  'Crystal Dynamics' 'Square Enix ' 'mixi, Inc' 'Pinnacle' 'SCi' 'Quelle'
#  'Rage Software' 'Ubisoft Annecy' 'Interplay' 'Scholastic Inc.' 'Mystique'
#  'ChunSoft' 'Square EA' '20th Century Fox Video Games'
#  'Hudson Entertainment' 'Men-A-Vision' 'Nobilis' 'Avanquest Software'
#  'Big Ben Interactive' 'Nordic Games' 'Touchstone' 'Spike'
#  'Nippon Ichi Software' 'Sony Computer Entertainment America'
#  'Jester Interactive' 'LEGO Media' 'Quest' 'Illusion Softworks'
#  'Tigervision' 'Rocket Company' 'Metro 3D' 'Mattel Interactive'
#  'IE Institute' 'Funbox Media' 'Rondomedia' 'Universal Gamex' 'Ghostlight'
#  'Wizard Video Games' 'BMG Interactive Entertainment' 'PQube'
#  'Trion Worlds' 'Xseed Games' 'Laguna' 'Takara' 'Ignition Entertainment'
#  'Kadokawa Shoten' 'Enterbrain' 'Imagineer' 'CPG Products'
#  'System 3 Arcade Software' 'Aruze Corp' 'Destineer' 'Gamebridge'
#  'Midas Interactive Entertainment' 'Jaleco' 'Answer Software'
#  'Pack In Soft' 'XS Games' 'Rebellion' 'Harmonix Music Systems'
#  'Activision Blizzard' 'Xplosiv' 'Wanadoo' 'Telltale Games' 'NovaLogic'
#  'Epoch' 'BAM! Entertainment' 'GameMill Entertainment'
#  'Knowledge Adventure' 'Tetris Online' 'Mastiff' 'ESP' 'TYO' 'Telegames'
#  'Mud Duck Productions' 'Screenlife' 'Pioneer LDC' 'Magical Company'
#  'Kemco' 'Mentor Interactive' 'Human Entertainment' 'Data Age'
#  'Electronic Arts Victor' 'Jack of All Games' 'Avanquest'
#  'Black Bean Games' '989 Sports' 'Takara Tomy' 'Media Rings' 'Elf'
#  'Starfish' 'Zushi Games' 'Jorudan' 'Destination Software, Inc' 'New'
#  'Brash Entertainment' 'ITT Family Games' 'Ackkstudios' 'PopCap Games'
#  'Starpath Corp.' 'BPS' 'Gathering of Developers' 'NewKidCo'
#  'Marvelous Interactive' 'Storm City Games' 'CokeM Interactive'
#  'Kalypso Media' 'P2 Games' 'CBS Electronics'
#  'Home Entertainment Suppliers' 'Magix' 'Arc System Works' 'Angel Studios'
#  'Wargaming.net' 'Playmates' 'SNK Playmore' 'Hamster Corporation'
#  'From Software' 'Nippon Columbia' 'Nichibutsu' 'Conspiracy Entertainment'
#  'Hect' 'Mumbo Jumbo' 'DTP Entertainment' 'Pacific Century Cyber Works'
#  'Indie Games' 'Liquid Games' 'NEC' 'Axela' 'ArtDink' 'Sunsoft'
#  'Little Orbit' 'FuRyu' 'Gust' 'SNK' 'NEC Interchannel'
#  'Nihon Falcom Corporation' 'Xing Entertainment' 'ValuSoft'
#  'Victor Interactive' 'American Softworks' 'Falcom Corporation'
#  'Detn8 Games' 'Bomb' 'Nordcurrent' 'Milestone S.r.l.' 'AQ Interactive'
#  'Seta Corporation' 'On Demand' 'CCP' 'NCS' 'Rebellion Developments'
#  'Agatsuma Entertainment' 'Gremlin Interactive Ltd' 'Aspyr'
#  'Compile Heart' 'Culture Brain' 'Mad Catz' 'Shogakukan' 'Merscom LLC'
#  'JoWood Productions' 'Nippon Telenet' 'TDK Core' 'Kadokawa Games' 'SSI'
#  'Foreign Media Games' 'Core Design Ltd.' 'bitComposer Games' 'Astragon'
#  'Asylum Entertainment' 'Performance Designed Products' 'UFO Interactive'
#  'Essential Games' 'Adeline Software' 'Funcom' 'PlayV' 'Panther Software'
#  'Blast! Entertainment Ltd' 'Playlogic Game Factory' 'DSI Games'
#  'Avalon Interactive' 'Game Life' 'Popcorn Arcade' 'Aques' 'System 3'
#  'Syscom' 'Vir2L Studios' 'Vatical Entertainment' 'Neko Entertainment'
#  'White Park Bay Software' 'Vic Tokai' 'Media Factory' 'Daedalic'
#  'Game Arts' 'The Adventure Company' 'EA Games' 'Acquire' 'Broccoli'
#  'General Entertainment' 'Paradox Interactive' 'Yacht Club Games' 'Imadio'
#  'Swing! Entertainment' 'Sony Music Entertainment' 'Aqua Plus'
#  'Excalibur Publishing' 'Hip Interactive' 'Tripwire Interactive'
#  'DreamCatcher Interactive' 'SCS Software' 'Havas Interactive' 'Sting'
#  'Idea Factory' 'Telstar' 'U.S. Gold' 'Funsta' 'DreamWorks Interactive'
#  'Slitherine Software' 'MTO' 'Graffiti' 'Tru Blu Entertainment'
#  'DHM Interactive' 'Crytek' 'FunSoft' 'Data Design Interactive' 'SPS'
#  'Moss' 'T&E Soft' 'NDA Productions' 'Bigben Interactive' 'Data East'
#  'Idea Factory International' 'Time Warner Interactive'
#  'Gainax Network Systems' 'Daito' 'O3 Entertainment' 'O-Games' 'Gameloft'
#  'Xicat Interactive' 'Simon & Schuster Interactive' 'Valcon Games'
#  'PopTop Software' 'TOHO' 'PM Studios' 'Bohemia Interactive'
#  'Reef Entertainment' '5pb' 'HMH Interactive' 'inXile Entertainment'
#  'Cave' 'Microids' 'Paon' 'CDV Software Entertainment' 'Micro Cabin'
#  'GameTek' 'Benesse' 'Type-Moon' 'Enjoy Gaming ltd.' 'Asmik Corp'
#  'Interplay Productions' 'Asmik Ace Entertainment' 'Image Epoch'
#  'Phantom EFX' 'Evolved Games' 'responDESIGN' 'Griffin International'
#  'Culture Publishers' 'Hackberry' 'Hearty Robin' 'Nippon Amuse'
#  'Origin Systems' 'Seventh Chord' 'Abylight' 'Mitsui' 'Insomniac Games'
#  'Flight-Plan' 'Milestone' 'Glams' 'Aksys Games' 'Locus' 'Warp'
#  'Irem Software Engineering' 'Myelin Media' 'Global A Entertainment'
#  'Alternative Software' 'Mercury Games' 'Sunrise Interactive' 'Elite'
#  'Evolution Games' 'Daedalic Entertainment' 'Edia' 'Athena' 'Aria'
#  'Tivola' 'Happinet' 'Tommo' 'Altron' 'Revolution Software' 'Media Works'
#  'Fortyfive' 'Gamecock' 'Imax' '10TACLE Studios' 'Groove Games'
#  'Pack-In-Video' 'Crimson Cow' 'iWin' 'Asgard' 'Ecole' 'Yumedia'
#  'Ascaron Entertainment GmbH' 'HAL Laboratory' 'Phenomedia'
#  'Grand Prix Games' 'DigiCube' 'Creative Core' 'Kaga Create'
#  'WayForward Technologies' 'LSP Games' 'ASCII Media Works' '1C Company'
#  'Coconuts Japan' 'Arika' 'Marvel Entertainment' 'Ertain' 'Prototype'
#  'Phantagram' 'The Learning Company' 'TechnoSoft' 'MLB.com' 'Vap' 'Misawa'
#  'Yeti' 'Dusenberry Martin Racing' 'Navarre Corp' 'Pow' 'MediaQuest'
#  'Team17 Software' 'Max Five' 'Tradewest' 'Comfort' 'Milestone S.r.l'
#  'Pony Canyon' 'Riverhillsoft' 'Summitsoft' 'Playmore' 'Kool Kizz'
#  'Monte Christo Multimedia' 'Legacy Interactive'
#  'Cloud Imperium Games Corporation' 'Flashpoint Games' 'CyberFront'
#  'Alawar Entertainment' 'Societa' 'Interchannel' 'Experience Inc.'
#  'Sonnet' 'Virtual Play Games' 'Zenrin' 'Iceberg Interactive' 'Ivolgamus'
#  'MC2 Entertainment' '2D Boy' 'Games Workshop' 'Kando Games'
#  'Office Create' 'Maximum Family Games' 'Fields' 'Gearbox Software'
#  'Princess Soft' 'Extreme Entertainment Group' 'Big Fish Games' 'Berkeley'
#  'Mamba Games' 'Fuji' 'FuRyu Corporation' 'Her Interactive'
#  'imageepoch Inc.' 'Just Flight' 'Kamui' 'ASK' 'Cygames'
#  'Introversion Software' '49Games' 'KSS' 'dramatic create' 'TGL' 'KID'
#  'Quinrose' 'Sold Out' 'Encore' 'G.Rev' 'Sunflowers' 'Headup Games'
#  'Sweets' 'Kokopeli Digital Studios' 'id Software' 'Nexon' 'BushiRoad'
#  'Devolver Digital' 'Number None' 'Tryfirst' 'TopWare Interactive'
#  'GN Software' "Yuke's" 'Strategy First' 'Lexicon Entertainment'
#  'Paon Corporation' 'Kids Station' 'Licensed 4U' 'GOA' '7G//AMES'
#  'King Records' 'Minato Station' 'Graphsim Entertainment'
#  'Easy Interactive' 'Gaga' 'Yamasa Entertainment' 'Plenty' 'Views'
#  'Blue Byte' 'fonfun' 'NetRevo' 'Epic Games' 'Quintet' 'Focus Multimedia'
#  'Phoenix Games' 'Marvelous Games' 'Dorart' 'Codemasters Online'
#  'Stainless Games' 'Aerosoft' 'Imageworks' 'Karin Entertainment'
#  'Technos Japan Corporation' 'Masque Publishing' 'Gakken'
#  'New World Computing' 'Mirai Shounen' 'Datam Polystar' 'HuneX' 'Visco'
#  'Saurus' 'Revolution (Japan)' 'Giza10' 'Alvion' 'Giga' 'Mycom' 'Warashi'
#  'System Soft' 'RED Entertainment' 'Lighthouse Interactive' 'Michaelsoft'
#  'Media Entertainment' 'Genterprise' 'Interworks Unlimited, Inc.'
#  'Inti Creates' 'Boost On' 'EON Digital Entertainment' 'Nitroplus'
#  'Naxat Soft' 'Piacci' 'Paradox Development' 'Otomate'
#  'Ascaron Entertainment' 'Ongakukan' 'Commseed' 'UIG Entertainment'
#  'Takuyo' 'Interchannel-Holon' 'Red Flagship']
# ['8' nan '8.3' '8.5' '6.6' '8.4' '8.6' '7.7' '6.3' '7.4' '8.2' '9' '7.9'
#  '8.1' '8.7' '7.1' '3.4' '5.3' '4.8' '3.2' '8.9' '6.4' '7.8' '7.5' '2.6'
#  '7.2' '9.2' '7' '7.3' '4.3' '7.6' '5.7' '5' '9.1' '6.5' 'tbd' '8.8' '6.9'
#  '9.4' '6.8' '6.1' '6.7' '5.4' '4' '4.9' '4.5' '9.3' '6.2' '4.2' '6' '3.7'
#  '4.1' '5.8' '5.6' '5.5' '4.4' '4.6' '5.9' '3.9' '3.1' '2.9' '5.2' '3.3'
#  '4.7' '5.1' '3.5' '2.5' '1.9' '3' '2.7' '2.2' '2' '9.5' '2.1' '3.6' '2.8'
#  '1.8' '3.8' '0' '1.6' '9.6' '2.4' '1.7' '1.1' '0.3' '1.5' '0.7' '1.2'
#  '2.3' '0.5' '1.3' '0.2' '0.6' '1.4' '0.9' '1' '9.7']
# ['Nintendo' nan 'Good Science Studio' ... 'Big Red Software'
#  'Atomic Games' 'Interchannel-Holon']
# ['E' nan 'M' 'T' 'E10+' 'K-A' 'AO' 'EC' 'RP']

# %% [raw]
# Veo que salvo las categorías de Genre y Platform, el resto tienen muchos unique values.

# %%
catsGrafic= categoricas[1:3]
catsGrafic
# Out:
# ['Platform', 'Genre']

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import seaborn as sns
for i in catsGrafic:
  draw = sns.countplot(df[i])
  draw.set_xticklabels(draw.get_xticklabels(), rotation="vertical", ha="right")
  plt.show()

# %%
import seaborn as sns
for i in catsGrafic:
  draw = sns.countplot(df_con_resenaR[i])
  draw.set_xticklabels(draw.get_xticklabels(), rotation="45", ha="right")
  plt.show()

# %% [markdown]
# #  Acción y Deportes liderando siempre!

# %% [markdown]
# ## Play2 y Xbox 360 las dos consolas más populares

# %% [markdown]
# Vamos a hacer también un count para el año!

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
draw= sns.countplot(df["Year_of_Release"],  palette="summer")
draw.set_xticklabels(draw.get_xticklabels(), rotation="vertical", ha="right")
plt.show()

# %%
df["Year_of_Release"].describe()
# Out:
# count    16448.000000
# mean      2006.488996
# std          5.877470
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2020.000000
# Name: Year_of_Release, dtype: float64

# %% [raw]
# 50% of the data is between 2003 and 2010.

# %% [markdown]
# ### Pasemos ahora  a las numéricas. El boxplot no me gusta, veamos la distribución.

# %%
numericas
# Out:
# ['Year_of_Release',
#  'NA_Sales',
#  'EU_Sales',
#  'JP_Sales',
#  'Other_Sales',
#  'Global_Sales',
#  'Critic_Score',
#  'Critic_Count',
#  'User_Count']

# %%
for i in numericas:
    draw= sns.histplot(df[i], bins= 10, kde= True)
    draw.set_xticklabels(draw.get_xticklabels(), rotation="vertical")
    plt.show()
# Out:
# <ipython-input-67-80e2967c17b8>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   draw.set_xticklabels(draw.get_xticklabels(), rotation="vertical")
# <ipython-input-67-80e2967c17b8>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   draw.set_xticklabels(draw.get_xticklabels(), rotation="vertical")
# <ipython-input-67-80e2967c17b8>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   draw.set_xticklabels(draw.get_xticklabels(), rotation="vertical")
# <ipython-input-67-80e2967c17b8>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   draw.set_xticklabels(draw.get_xticklabels(), rotation="vertical")
# <ipython-input-67-80e2967c17b8>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   draw.set_xticklabels(draw.get_xticklabels(), rotation="vertical")
# <ipython-input-67-80e2967c17b8>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   draw.set_xticklabels(draw.get_xticklabels(), rotation="vertical")
# <ipython-input-67-80e2967c17b8>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   draw.set_xticklabels(draw.get_xticklabels(), rotation="vertical")
# <ipython-input-67-80e2967c17b8>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   draw.set_xticklabels(draw.get_xticklabels(), rotation="vertical")
# <ipython-input-67-80e2967c17b8>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   draw.set_xticklabels(draw.get_xticklabels(), rotation="vertical")

# %% [raw]
# i´m not satisfied with the way the sales where graphed.

# %% [markdown]
# From a Kaggle collegue i found out the following function to plot in a more organized way.

# %%
def grafDistr(data, column, range_min=0, range_max=0, clr='blue'):
    print(f'1% percentile: {data[column].quantile(.1)}')
    print(f'50% percentile: {data[column].quantile(.50)}')
    print(f'99% percentile: {data[column].quantile(.99)}')  # me tira en texto a que altura está el 1%, el 50% y el 99%
  
    data1 = data.copy()
    fig = plt.figure(figsize=(15, 6)) 
    if range_min==range_max:
        range_min = data[column].min()
        range_max = data[column].max()
    else:
        data1 = data1[data1[column]<data1[column].quantile(range_max)]
        data1 =  data1[data1[column]>data1[column].quantile(range_min)]
    
    sns.histplot(data1[column], kde=True, bins=len(data1[column].unique()), color=clr)
    plt.title(f"{column} histogram")
    plt.ylabel(f"{column} count")
    plt.xlabel(column)

    plt.show()

# %%
grafDistr(df, "NA_Sales", range_max=0.99)
# Out:
# 1% percentile: 0.0
# 50% percentile: 0.08
# 99% percentile: 2.8053000000000066

# %%
grafDistr(df, "EU_Sales", range_max=0.99)
# Out:
# 1% percentile: 0.0
# 50% percentile: 0.02
# 99% percentile: 1.9453000000000065

# %%
grafDistr(df, "JP_Sales", range_max=0.99)
# Out:
# 1% percentile: 0.0
# 50% percentile: 0.0
# 99% percentile: 1.2753000000000065

# %%
grafDistr(df, "Global_Sales", range_max=0.99)
# Out:
# 1% percentile: 0.02
# 50% percentile: 0.17
# 99% percentile: 5.48

# %%
# Chequiemos a que se refiere con global sales, haciendo una nueva columna TOTAL SALES, sumando todos los datos que tenemos
df["total_sales"]= df["NA_Sales"] + df["EU_Sales"] + df["JP_Sales"]+ df["Other_Sales"]
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count User_Score  User_Count Developer Rating  \
# 0              76.0          51.0          8       322.0  Nintendo      E
# 1               NaN           NaN        NaN         NaN       NaN    NaN
# 2              82.0          73.0        8.3       709.0  Nintendo      E
# 3              80.0          73.0          8       192.0  Nintendo      E
# 4               NaN           NaN        NaN         NaN       NaN    NaN
# ...             ...           ...        ...         ...       ...    ...
# 16714           NaN           NaN        NaN         NaN       NaN    NaN
# 16715           NaN           NaN        NaN         NaN       NaN    NaN
# 16716           NaN           NaN        NaN         NaN       NaN    NaN
# 16717           NaN           NaN        NaN         NaN       NaN    NaN
# 16718           NaN           NaN        NaN         NaN       NaN    NaN
#
#        total_sales
# 0            82.54
# 1            40.24
# 2            35.52
# 3            32.77
# 4            31.38
# ...            ...
# 16714         0.01
# 16715         0.01
# 16716         0.01
# 16717         0.01
# 16718         0.01
#
# [16448 rows x 17 columns]

# %% [markdown]
# ## ¡Remember the sales are in millions!

# %%
grafDistr(df, "total_sales", range_max=0.99)
# Vemos que son casi lo mism que Global_Sales
# Out:
# 1% percentile: 0.02
# 50% percentile: 0.16999999999999998
# 99% percentile: 5.48

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Who are more demanding? Critics or users? Let's see the distribution

# %% [markdown]
# Let´s go back to our filled df.

# %%
grafDistr(df_con_resenaR, "Critic_Score", clr= "red")
# Out:
# 1% percentile: 52.0
# 50% percentile: 68.99436302142053
# 99% percentile: 93.0

# %% [raw]
# The high bar is because we filledNA with median! Remember!

# %%
# Agrego también el sin relleno para ver que el critic score ya tenía un pico en la mediana. 
draw1= grafDistr(df_con_resena, "Critic_Score", clr= "red")
# Out:
# 1% percentile: 50.0
# 50% percentile: 71.0
# 99% percentile: 94.0

# %%
grafDistr(df_con_resenaR, "User_Score", clr= "green")
# vemos que en user_score tenemos el tbd. Por lo tanto no me deja ver la distrib
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-a0c15bdb385e> in <module>
# ----> 1 grafDistr(df_con_resenaR, "User_Score", clr= "green")
#       2 # vemos que en user_score tenemos el tbd. Por lo tanto no me deja ver la distrib
#
# <ipython-input-64-4d40d57cac53> in grafDistr(data, column, range_min, range_max, clr)
#       1 def grafDistr(data, column, range_min=0, range_max=0, clr='blue'):
# ----> 2     print(f'1% percentile: {data[column].quantile(.1)}')
#       3     print(f'50% percentile: {data[column].quantile(.50)}')
#       4     print(f'99% percentile: {data[column].quantile(.99)}')  # me tira en texto a que altura está el 1%, el 50% y el 99%
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in quantile(self, q, interpolation)
#    2265         df = self.to_frame()
#    2266
# -> 2267         result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2268         if result.ndim == 2:
#    2269             result = result.iloc[:, 0]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in quantile(self, q, axis, numeric_only, interpolation)
#    9264             return self._constructor_sliced([], index=cols, name=q, dtype=np.float64)
#    9265
# -> 9266         result = data._mgr.quantile(
#    9267             qs=q, axis=1, interpolation=interpolation, transposed=is_transposed
#    9268         )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in quantile(self, axis, consolidate, transposed, interpolation, qs, numeric_only)
#     489         axes, blocks = [], []
#     490         for b in self.blocks:
# --> 491             block = b.quantile(axis=axis, qs=qs, interpolation=interpolation)
#     492
#     493             axe = get_axe(b, qs, axes=self.axes)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in quantile(self, qs, interpolation, axis)
#    1590             # asarray needed for Sparse, see GH#24600
#    1591             mask = np.asarray(isna(values))
# -> 1592             result = nanpercentile(
#    1593                 values,
#    1594                 np.array(qs) * 100,
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in nanpercentile(values, q, axis, na_value, mask, ndim, interpolation)
#    1673             return result
#    1674     else:
# -> 1675         return np.percentile(values, q, axis=axis, interpolation=interpolation)
#    1676
#    1677
#
# <__array_function__ internals> in percentile(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3730     if not _quantile_is_valid(q):
#    3731         raise ValueError("Percentiles must be in the range [0, 100]")
# -> 3732     return _quantile_unchecked(
#    3733         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3734
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3849                         interpolation='linear', keepdims=False):
#    3850     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 3851     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
#    3852                     overwrite_input=overwrite_input,
#    3853                     interpolation=interpolation)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3427         keepdim = (1,) * a.ndim
#    3428
# -> 3429     r = func(a, **kwargs)
#    3430     return r, keepdim
#    3431
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in _quantile_ureduce_func(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3965             n = np.isnan(ap[-1:, ...])
#    3966
# -> 3967         x1 = take(ap, indices_below, axis=axis) * weights_below
#    3968         x2 = take(ap, indices_above, axis=axis) * weights_above
#    3969
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# ### The above error is because, as we show below, between the user_score we have tbd, making the whole column an "object". We must drop this values and graph

# %%
df_con_resenaR.User_Score.unique()
# Out:
# array(['8', '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4', '8.2',
#        '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2', '8.9',
#        '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3', '7.6',
#        '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %%
user3= df_con_resenaR.loc[df_con_resenaR.User_Score != "tbd"]
user3["User_Score"]= user3["User_Score"].astype("float")
# Out:
# <ipython-input-78-a83def183264>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user3["User_Score"]= user3["User_Score"].astype("float")

# %%
user3.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
# Ahora que desechamos los tbd. Hagamos un count plot de los user_score
draw2= grafDistr(user3,"User_Score",clr="green")
# Out:
# 1% percentile: 5.1
# 50% percentile: 7.5
# 99% percentile: 9.2

# %% [markdown]
# We can see the main values for User´s score are higher than Critic Score

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Now let´s try to see sales by Platform

# %% [markdown]
# ### For that we will use the total_sales and the timeline. Grouping by Platform

# %%
df_con_resenaR.head()
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 2         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 3      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 6  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 7               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 6     11.28      9.14      6.50         2.88         29.80          89.0
# 7     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 6          65.0        8.5       431.0  Nintendo      E
# 7          41.0        6.6       129.0  Nintendo      E

# %%
# Vemos que el index ta en cualquiera
df1= df_con_resenaR.reset_index()
df1
# Out:
#       index                           Name Platform  Year_of_Release  \
# 0         0                     Wii Sports      Wii           2006.0
# 1         2                 Mario Kart Wii      Wii           2008.0
# 2         3              Wii Sports Resort      Wii           2009.0
# 3         6          New Super Mario Bros.       DS           2006.0
# 4         7                       Wii Play      Wii           2006.0
# ...     ...                            ...      ...              ...
# 9935  16702               Mega Brain Boost       DS           2008.0
# 9936  16706        STORM: Frontline Nation       PC           2011.0
# 9937  16708                       Plushees       DS           2008.0
# 9938  16709                        15 Days       PC           2009.0
# 9939  16710  Men in Black II: Alien Escape       GC           2003.0
#
#            Genre              Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0         Sports               Nintendo     41.36     28.96      3.77
# 1         Racing               Nintendo     15.68     12.76      3.79
# 2         Sports               Nintendo     15.61     10.93      3.28
# 3       Platform               Nintendo     11.28      9.14      6.50
# 4           Misc               Nintendo     13.96      9.18      2.93
# ...          ...                    ...       ...       ...       ...
# 9935      Puzzle  Majesco Entertainment      0.01      0.00      0.00
# 9936    Strategy                Unknown      0.00      0.01      0.00
# 9937  Simulation              Destineer      0.01      0.00      0.00
# 9938   Adventure      DTP Entertainment      0.00      0.01      0.00
# 9939     Shooter             Infogrames      0.01      0.00      0.00
#
#       Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# 0            8.45         82.53     76.000000          51.0          8
# 1            3.29         35.52     82.000000          73.0        8.3
# 2            2.95         32.77     80.000000          73.0          8
# 3            2.88         29.80     89.000000          65.0        8.5
# 4            2.84         28.92     58.000000          41.0        6.6
# ...           ...           ...           ...           ...        ...
# 9935         0.00          0.01     48.000000          10.0        tbd
# 9936         0.00          0.01     60.000000          12.0        7.2
# 9937         0.00          0.01     68.994363          22.0        tbd
# 9938         0.00          0.01     63.000000           6.0        5.8
# 9939         0.00          0.01     68.994363          22.0        tbd
#
#       User_Count           Developer Rating
# 0          322.0            Nintendo      E
# 1          709.0            Nintendo      E
# 2          192.0            Nintendo      E
# 3          431.0            Nintendo      E
# 4          129.0            Nintendo      E
# ...          ...                 ...    ...
# 9935        24.0  Interchannel-Holon      E
# 9936        13.0              SimBin   E10+
# 9937        24.0      Big John Games      E
# 9938         8.0   DTP Entertainment     RP
# 9939        24.0               Atari      T
#
# [9940 rows x 17 columns]

# %%
df1= df1.drop(axis= 1, columns= "index")

# %%
df1
# Out:
#                                Name Platform  Year_of_Release       Genre  \
# 0                        Wii Sports      Wii           2006.0      Sports
# 1                    Mario Kart Wii      Wii           2008.0      Racing
# 2                 Wii Sports Resort      Wii           2009.0      Sports
# 3             New Super Mario Bros.       DS           2006.0    Platform
# 4                          Wii Play      Wii           2006.0        Misc
# ...                             ...      ...              ...         ...
# 9935               Mega Brain Boost       DS           2008.0      Puzzle
# 9936        STORM: Frontline Nation       PC           2011.0    Strategy
# 9937                       Plushees       DS           2008.0  Simulation
# 9938                        15 Days       PC           2009.0   Adventure
# 9939  Men in Black II: Alien Escape       GC           2003.0     Shooter
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                  Nintendo     41.36     28.96      3.77         8.45
# 1                  Nintendo     15.68     12.76      3.79         3.29
# 2                  Nintendo     15.61     10.93      3.28         2.95
# 3                  Nintendo     11.28      9.14      6.50         2.88
# 4                  Nintendo     13.96      9.18      2.93         2.84
# ...                     ...       ...       ...       ...          ...
# 9935  Majesco Entertainment      0.01      0.00      0.00         0.00
# 9936                Unknown      0.00      0.01      0.00         0.00
# 9937              Destineer      0.01      0.00      0.00         0.00
# 9938      DTP Entertainment      0.00      0.01      0.00         0.00
# 9939             Infogrames      0.01      0.00      0.00         0.00
#
#       Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 0            82.53     76.000000          51.0          8       322.0
# 1            35.52     82.000000          73.0        8.3       709.0
# 2            32.77     80.000000          73.0          8       192.0
# 3            29.80     89.000000          65.0        8.5       431.0
# 4            28.92     58.000000          41.0        6.6       129.0
# ...            ...           ...           ...        ...         ...
# 9935          0.01     48.000000          10.0        tbd        24.0
# 9936          0.01     60.000000          12.0        7.2        13.0
# 9937          0.01     68.994363          22.0        tbd        24.0
# 9938          0.01     63.000000           6.0        5.8         8.0
# 9939          0.01     68.994363          22.0        tbd        24.0
#
#                Developer Rating
# 0               Nintendo      E
# 1               Nintendo      E
# 2               Nintendo      E
# 3               Nintendo      E
# 4               Nintendo      E
# ...                  ...    ...
# 9935  Interchannel-Holon      E
# 9936              SimBin   E10+
# 9937      Big John Games      E
# 9938   DTP Entertainment     RP
# 9939               Atari      T
#
# [9940 rows x 16 columns]

# %% [markdown]
# Para lo que yo quiero hacer, tendría que agrupar por YearofRelease, agrupar por Platform, y después sumar las GlobalSales, y UserCounts

# %% [raw]
# Hagamos un df separado con estas cols

# %%
df_group= df1.loc[:, ["Year_of_Release", "Platform", "Global_Sales", "User_Count"]]
df_group
# Out:
#       Year_of_Release Platform  Global_Sales  User_Count
# 0              2006.0      Wii         82.53       322.0
# 1              2008.0      Wii         35.52       709.0
# 2              2009.0      Wii         32.77       192.0
# 3              2006.0       DS         29.80       431.0
# 4              2006.0      Wii         28.92       129.0
# ...               ...      ...           ...         ...
# 9935           2008.0       DS          0.01        24.0
# 9936           2011.0       PC          0.01        13.0
# 9937           2008.0       DS          0.01        24.0
# 9938           2009.0       PC          0.01         8.0
# 9939           2003.0       GC          0.01        24.0
#
# [9940 rows x 4 columns]

# %%
# sum = df.groupby(["year", "month"]).agg({"score": "sum", "num_attempts": "sum"}).reset_index()
grupi= df_group.groupby(["Year_of_Release", "Platform"]).agg({"Global_Sales": "sum", "User_Count": "sum"}).reset_index()

# %%
# Otra forma de hacerlo.
# df_sales_by_year = df.pivot_table(index = ['year',
                                          # 'platform'], 
                                  #values = 'sum_sales', 
                                  #aggfunc = 'sum').reset_index()
# df_sales_by_year

# %%
grupi["Year_of_Release"]= grupi["Year_of_Release"].astype("int")

# %%
grupi
# Out:
#      Year_of_Release Platform  Global_Sales  User_Count
# 0               1985       PC          0.03        19.0
# 1               1988       PC          0.03      4572.0
# 2               1992       PC          0.81      1820.0
# 3               1994       PS          1.27         4.0
# 4               1996       PC          2.62      4402.0
# ..               ...      ...           ...         ...
# 145             2016      Wii          0.18        24.0
# 146             2016     WiiU          3.56      1806.0
# 147             2016     X360          1.49       206.0
# 148             2016     XOne         24.27      9922.0
# 149             2020       DS          0.29        24.0
#
# [150 rows x 4 columns]

# %%
grupi["Platform"].unique()
# Out:
# array(['PC', 'PS', 'DC', 'PS2', 'XB', 'GBA', 'GC', 'DS', 'PSP', 'X360',
#        'PS3', 'Wii', '3DS', 'PSV', 'WiiU', 'PS4', 'XOne'], dtype=object)

# %%
fig, ax = plt.subplots(figsize= (12,10))

grouped = grupi.groupby('Platform')
for key, group in grouped:
    group.plot(ax=ax, kind='line', x='Year_of_Release', y='Global_Sales', label=key)
plt.show()

# %% [markdown]
# This is the central idea of the graph. It is not that nice... too much lines and legends.

# %% [markdown]
# Let´s do a bar graph as the one we made with COUNT.

# %% [markdown]
# We can also see the year most videogames were sold.

# %%
sns.set_theme(style="whitegrid")
sns.barplot(x= "Platform", y= "Global_Sales", data= grupi, palette="Blues_d", capsize= 0)
# Out:
# <AxesSubplot:xlabel='Platform', ylabel='Global_Sales'>

# %%
grupi
# Out:
#      Year_of_Release Platform  Global_Sales  User_Count
# 0               1985       PC          0.03        19.0
# 1               1988       PC          0.03      4572.0
# 2               1992       PC          0.81      1820.0
# 3               1994       PS          1.27         4.0
# 4               1996       PC          2.62      4402.0
# ..               ...      ...           ...         ...
# 145             2016      Wii          0.18        24.0
# 146             2016     WiiU          3.56      1806.0
# 147             2016     X360          1.49       206.0
# 148             2016     XOne         24.27      9922.0
# 149             2020       DS          0.29        24.0
#
# [150 rows x 4 columns]

# %%
grupi.groupby('Platform')['Platform'].count().sort_values(ascending = False)
# Out:
# Platform
# PC      24
# PS2     12
# X360    12
# PS3     11
# Wii     11
# DS      11
# PSP     10
# XB       9
# PS       8
# GBA      7
# GC       7
# 3DS      6
# PSV      6
# WiiU     5
# PS4      4
# XOne     4
# DC       3
# Name: Platform, dtype: int64

# %%
grupi.groupby("Platform")["Global_Sales"].sum().sort_values(ascending= False)
# Out:
# Platform
# PS2     1045.40
# X360     901.72
# PS3      839.93
# Wii      796.92
# DS       562.30
# PS4      248.17
# PS       238.05
# XB       229.54
# PSP      213.48
# PC       210.58
# GBA      188.79
# GC       171.56
# XOne     134.99
# 3DS      132.50
# WiiU      67.98
# PSV       35.01
# DC         4.55
# Name: Global_Sales, dtype: float64

# %% [markdown]
# ## Best Platform= PS2

# %%
best_year= grupi.groupby("Year_of_Release")["Global_Sales"].sum().sort_values(ascending=False)

# %%
best_year
# Out:
# Year_of_Release
# 2008    589.94
# 2009    562.16
# 2007    516.92
# 2010    496.83
# 2006    440.71
# 2011    429.31
# 2005    361.75
# 2004    347.16
# 2002    320.40
# 2012    304.48
# 2013    284.63
# 2003    278.09
# 2001    276.25
# 2014    250.88
# 2015    186.32
# 2016     99.52
# 2000     95.96
# 1999     56.35
# 1998     52.57
# 1997     48.46
# 1996     20.35
# 1994      1.27
# 1992      0.81
# 2020      0.29
# 1988      0.03
# 1985      0.03
# Name: Global_Sales, dtype: float64

# %% [markdown]
# ## Best Year= 2008

# %%
# All this belonged to the df_con_reseñaR, let´s try to do it with df, our initial dataframe
# sum = df.groupby(["year", "month"]).agg({"score": "sum", "num_attempts": "sum"}).reset_index()
df_grouped= df.groupby(["Year_of_Release", "Platform"]).agg({"Global_Sales": "sum", "User_Count": "sum"}).reset_index()

# %%
best_total_platform= df_grouped.groupby("Platform")["Global_Sales"].sum().sort_values(ascending= False)
best_total_platform
# Out:
# Platform
# PS2     1233.46
# X360     961.39
# PS3      931.15
# Wii      891.74
# DS       803.73
# PS       727.41
# PS4      314.23
# GBA      313.56
# PSP      289.79
# 3DS      257.92
# PC       256.56
# GB       254.42
# XB       252.09
# NES      251.07
# N64      218.21
# SNES     200.05
# GC       197.14
# XOne     159.44
# 2600      86.57
# WiiU      82.16
# PSV       53.85
# SAT       33.59
# GEN       28.36
# DC        15.97
# SCD        1.87
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: Global_Sales, dtype: float64

# %%
best_total_year= df_grouped.groupby("Year_of_Release")["Global_Sales"].sum().sort_values(ascending=False)
best_total_year
# Out:
# Year_of_Release
# 2008.0    671.79
# 2009.0    658.88
# 2007.0    605.37
# 2010.0    590.59
# 2006.0    518.22
# 2011.0    507.79
# 2005.0    458.31
# 2004.0    419.05
# 2002.0    395.51
# 2013.0    361.24
# 2003.0    357.80
# 2012.0    355.84
# 2014.0    331.51
# 2001.0    331.47
# 2015.0    268.05
# 1998.0    256.45
# 1999.0    251.25
# 2000.0    201.58
# 1997.0    200.98
# 1996.0    199.15
# 2016.0    130.10
# 1995.0     88.11
# 1994.0     79.18
# 1992.0     76.17
# 1989.0     73.45
# 1985.0     53.94
# 1984.0     50.36
# 1990.0     49.39
# 1988.0     47.22
# 1993.0     45.98
# 1986.0     37.07
# 1981.0     35.77
# 1991.0     32.23
# 1982.0     28.86
# 1987.0     21.74
# 1983.0     16.79
# 1980.0     11.38
# 2020.0      0.29
# 2017.0      0.06
# Name: Global_Sales, dtype: float64

# %% [markdown]
# ## Best Platform is still PS2 and best year is still 2008

# %% [markdown]
# Primero grafiquemos en el tiempo únicamente a los que tienen más de 200 millones de ventas

# %%
def lineas(data, categ_column, x, y, lines, labels=['','','']):
    
    fig = plt.figure(figsize=(15, 6)) 
    for i in lines:
        plot_data = data[data[categ_column]==i]
        plt.plot( 
            plot_data[x],
            plot_data[y], 
            linestyle= '-', 
             marker='o',
            linewidth=2, 
            alpha=0.9,
            )
    plt.grid(True)
    plt.title(labels[0])
    plt.xlabel(labels[1])
    plt.ylabel(labels[2])
    plt.legend(lines)
    plt.show()

# %% [markdown]
# ## More than 200 mill Sales

# %%
labels = ['Total sales of TOP Platforms with more than 200 million by year','Year','Number of games sold, in millions']
lineas(grupi, 
                'Platform', 
                'Year_of_Release', 
                'Global_Sales', 
                ['PS2', "X360", "PS3", "Wii", "DS", "PS4", "PS", "XB", "PSP", "PC"],
               labels)

# %% [markdown]
# ## From 2000 to 2015.

# %%
siglo21= grupi.loc[grupi["Year_of_Release"]>= 2000]

# %%
labels = ['Total sales of TOP Platforms 21st Century','Year','Number of games sold, in millions']
lineas(siglo21, 
                'Platform', 
                'Year_of_Release', 
                'Global_Sales', 
                ['PS2', "X360", "PS3", "Wii", "DS", "PS4", "PS", "XB", "PSP", "PC"],
               labels)

# %% [markdown]
# ## Let´s do a comparison between the main companies.

# %%
siglo21["company"]= siglo21["Platform"]
# Out:
# <ipython-input-118-0c21be20d79b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   siglo21["company"]= siglo21["Platform"]

# %%
siglo21["company"]= siglo21["company"].replace(to_replace={"XB":"Microsoft", "X360":"Microsoft", "XOne":"Microsoft", "PC":"Microsoft", "DC": "Nintendo",
                                                          "PS": "PlayStation", "PS2": "PlayStation", "PS3": "PlayStation", "PS4": "PlayStation", "PSP":"PlayStation",
                                                          "PSV":"PlayStation", "GBA":"Nintendo", "DS": "Nintendo", "GC":"Nintendo", "3DS":"Nintendo",
                                                           "GB":"Nintendo", "Wii":"Nintendo", "WiiU":"Nintendo"}, value= None)
# Out:
# <ipython-input-119-608b8465a95f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   siglo21["company"]= siglo21["company"].replace(to_replace={"XB":"Microsoft", "X360":"Microsoft", "XOne":"Microsoft", "PC":"Microsoft", "DC": "Nintendo",

# %% [raw]
# There are 3 big companies that span all the VideoGames Platforms. This are PlayStation (for all the PS prototypes), Nintendo (for all the GameBoys and Wii), and Microsoft( owner of Xbox and Xbox 360). I also considered the PC games as part of Microsoft!

# %% [raw]
# Notice we add DC (sega) to Nintendo since this company owns most of its property rights.

# %%
siglo21
# Out:
#      Year_of_Release Platform  Global_Sales  User_Count      company
# 13              2000       DC          1.98       282.0     Nintendo
# 14              2000       PC          3.34      2611.0    Microsoft
# 15              2000       PS         55.95      3256.0  PlayStation
# 16              2000      PS2         33.70      1252.0  PlayStation
# 17              2000       XB          0.99        10.0    Microsoft
# ..               ...      ...           ...         ...          ...
# 145             2016      Wii          0.18        24.0     Nintendo
# 146             2016     WiiU          3.56      1806.0     Nintendo
# 147             2016     X360          1.49       206.0    Microsoft
# 148             2016     XOne         24.27      9922.0    Microsoft
# 149             2020       DS          0.29        24.0     Nintendo
#
# [137 rows x 5 columns]

# %%
siglo21.groupby("company")["Global_Sales"].sum().sort_values(ascending= False)
# Out:
# company
# PlayStation    2462.32
# Nintendo       1922.56
# Microsoft      1456.72
# Name: Global_Sales, dtype: float64

# %%
compas= siglo21.groupby(["Year_of_Release", "company"]).agg({"Global_Sales": "sum"}).reset_index()
compas
# Out:
#     Year_of_Release      company  Global_Sales
# 0              2000    Microsoft          4.33
# 1              2000     Nintendo          1.98
# 2              2000  PlayStation         89.65
# 3              2001    Microsoft         27.38
# 4              2001     Nintendo         73.98
# 5              2001  PlayStation        174.89
# 6              2002    Microsoft         52.63
# 7              2002     Nintendo         84.73
# 8              2002  PlayStation        183.04
# 9              2003    Microsoft         53.38
# 10             2003     Nintendo         74.79
# 11             2003  PlayStation        149.92
# 12             2004    Microsoft         72.28
# 13             2004     Nintendo         77.94
# 14             2004  PlayStation        196.94
# 15             2005    Microsoft         56.72
# 16             2005     Nintendo        136.19
# 17             2005  PlayStation        168.84
# 18             2006    Microsoft         59.90
# 19             2006     Nintendo        235.15
# 20             2006  PlayStation        145.66
# 21             2007    Microsoft        100.09
# 22             2007     Nintendo        248.02
# 23             2007  PlayStation        168.81
# 24             2008    Microsoft        141.53
# 25             2008     Nintendo        268.00
# 26             2008  PlayStation        180.41
# 27             2009    Microsoft        130.04
# 28             2009     Nintendo        261.11
# 29             2009  PlayStation        171.01
# 30             2010    Microsoft        184.18
# 31             2010     Nintendo        157.80
# 32             2010  PlayStation        154.85
# 33             2011    Microsoft        167.65
# 34             2011     Nintendo        113.39
# 35             2011  PlayStation        148.27
# 36             2012    Microsoft        118.72
# 37             2012     Nintendo         75.81
# 38             2012  PlayStation        109.95
# 39             2013    Microsoft        104.85
# 40             2013     Nintendo         44.38
# 41             2013  PlayStation        135.40
# 42             2014    Microsoft         91.38
# 43             2014     Nintendo         33.81
# 44             2014  PlayStation        125.69
# 45             2015    Microsoft         60.95
# 46             2015     Nintendo         29.07
# 47             2015  PlayStation         96.30
# 48             2016    Microsoft         30.71
# 49             2016     Nintendo          6.12
# 50             2016  PlayStation         62.69
# 51             2020     Nintendo          0.29

# %%
Nint= compas.loc[compas["company"]== "Nintendo"]
PS= compas.loc[compas["company"]== "PlayStation"]
Mic= compas.loc[compas["company"]=="Microsoft"]

# %%
maxnin= Nint["Global_Sales"].max()
maxPs= PS["Global_Sales"].max()
maxMic= Mic["Global_Sales"].max()

# %%
print(maxnin)
print(maxPs)
print(maxMic)
# Out:
# 268.0
# 196.9399999999999
# 184.1799999999999

# %%
fig, ax = plt.subplots(figsize=(20,12))
ax.plot(Nint["Year_of_Release"], Nint["Global_Sales"], label="Nintendo Sales", linewidth= 4)
ax.plot(PS["Year_of_Release"], PS["Global_Sales"], label="PlayStation Sales", linewidth= 4)
ax.plot(Mic["Year_of_Release"], Mic["Global_Sales"], label="Microsoft Sales", linewidth= 4)
ax.axhline(maxnin, linestyle="--", color= "b")
ax.axhline(maxPs, linestyle="--", color="orange")
ax.axhline(maxMic, linestyle="--", color="g")
ax.set_title("Sales by Company, in millions", size= "20", fontweight= "bold" )
ax.set_ylabel("Sales", size= "16")
ax.set_xlabel("Year", size= "16")
ax.legend(prop={'size': 16})
plt.show()

# %% [markdown]
# The graph show the highest sales for each company. Being 2008 for Nintendo, 2004 for PlayStation, and 2010 for Microsoft.

# %% [markdown]
# This results are not convincing to me... I believe that if we went back to the first dataset with the blanks the conclusions can be different.

# %%
# df was our first dataset. Lets group by year, platform and global sales as we did. 
siglo21bis= df.loc[df["Year_of_Release"]>= 2000]

# %%
grupi2= siglo21bis.groupby(["Year_of_Release", "Platform"]).agg({"Global_Sales":"sum"}).reset_index()

# %%
grupi2
# Out:
#      Year_of_Release Platform  Global_Sales
# 0             2000.0       DC          5.99
# 1             2000.0       GB         19.76
# 2             2000.0      GBA          0.06
# 3             2000.0      N64         34.01
# 4             2000.0       PC          4.68
# ..               ...      ...           ...
# 148           2016.0     X360          1.52
# 149           2016.0     XOne         26.27
# 150           2017.0      PS4          0.04
# 151           2017.0      PSV          0.02
# 152           2020.0       DS          0.29
#
# [153 rows x 3 columns]

# %%
grupi2["company"]= grupi2["Platform"]
grupi2["company"]= grupi2["company"].replace(to_replace={"XB":"Microsoft", "X360":"Microsoft", "XOne":"Microsoft", "PC":"Microsoft", "DC": "Nintendo",
                                                          "PS": "PlayStation", "PS2": "PlayStation", "PS3": "PlayStation", "PS4": "PlayStation", "PSP":"PlayStation",
                                                          "PSV":"PlayStation", "GBA":"Nintendo", "DS": "Nintendo", "GC":"Nintendo", "3DS":"Nintendo",
                                                           "GB":"Nintendo", "Wii":"Nintendo", "WiiU":"Nintendo"}, value= None)

# %%
grupi2
# Out:
#      Year_of_Release Platform  Global_Sales      company
# 0             2000.0       DC          5.99     Nintendo
# 1             2000.0       GB         19.76     Nintendo
# 2             2000.0      GBA          0.06     Nintendo
# 3             2000.0      N64         34.01          N64
# 4             2000.0       PC          4.68    Microsoft
# ..               ...      ...           ...          ...
# 148           2016.0     X360          1.52    Microsoft
# 149           2016.0     XOne         26.27    Microsoft
# 150           2017.0      PS4          0.04  PlayStation
# 151           2017.0      PSV          0.02  PlayStation
# 152           2020.0       DS          0.29     Nintendo
#
# [153 rows x 4 columns]

# %%
grupi3= grupi2.groupby(["Year_of_Release", "company"]).agg({"Global_Sales":"sum"}).reset_index()

# %%
labels = ['Total sales of TOP Platforms 21st Century','Year','Number of games sold, in millions']
lineas(grupi3, 
                'company', 
                'Year_of_Release', 
                'Global_Sales', 
                ["Nintendo", "PlayStation", "Microsoft"],
               labels)

# %%
grupi3.groupby("company")["Global_Sales"].sum().sort_values(ascending= False)
# Out:
# company
# PlayStation    2963.04
# Nintendo       2582.64
# Microsoft      1579.46
# N64              37.35
# WS                0.96
# Name: Global_Sales, dtype: float64

# %% [raw]
# My hipothesis is FALSE. The Global_Sales patterns are the same one with the clean dataset and with the initial one.

# %% [markdown]
# --------------------------------------------------------------------------

# %% [markdown]
# # Football Games

# %%
deportes= df.loc[df["Genre"]== "Sports"]
deportes
# Out:
#                                 Name Platform  Year_of_Release   Genre  \
# 0                         Wii Sports      Wii           2006.0  Sports
# 3                  Wii Sports Resort      Wii           2009.0  Sports
# 13                           Wii Fit      Wii           2007.0  Sports
# 15                      Wii Fit Plus      Wii           2009.0  Sports
# 77                           FIFA 16      PS4           2015.0  Sports
# ...                              ...      ...              ...     ...
# 16680               G1 Jockey 4 2008      PS3           2008.0  Sports
# 16692  Outdoors Unleashed: Africa 3D      3DS           2011.0  Sports
# 16697              PGA European Tour      N64           2000.0  Sports
# 16704       Mezase!! Tsuri Master DS       DS           2009.0  Sports
# 16715               LMA Manager 2007     X360           2006.0  Sports
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0             Nintendo     41.36     28.96      3.77         8.45
# 3             Nintendo     15.61     10.93      3.28         2.95
# 13            Nintendo      8.92      8.03      3.60         2.15
# 15            Nintendo      9.01      8.49      2.53         1.77
# 77     Electronic Arts      1.12      6.12      0.06         1.28
# ...                ...       ...       ...       ...          ...
# 16680       Tecmo Koei      0.00      0.00      0.00         0.00
# 16692          Mastiff      0.01      0.00      0.00         0.00
# 16697       Infogrames      0.01      0.00      0.00         0.00
# 16704      Hudson Soft      0.00      0.00      0.01         0.00
# 16715      Codemasters      0.00      0.01      0.00         0.00
#
#        Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 0             82.53          76.0          51.0          8       322.0
# 3             32.77          80.0          73.0          8       192.0
# 13            22.70          80.0          63.0        7.7       146.0
# 15            21.79          80.0          33.0        7.4        52.0
# 77             8.57          82.0          42.0        4.3       896.0
# ...             ...           ...           ...        ...         ...
# 16680          0.01           NaN           NaN        NaN         NaN
# 16692          0.01           NaN           NaN        tbd         NaN
# 16697          0.01           NaN           NaN        NaN         NaN
# 16704          0.01           NaN           NaN        NaN         NaN
# 16715          0.01           NaN           NaN        NaN         NaN
#
#        Developer Rating  total_sales
# 0       Nintendo      E        82.54
# 3       Nintendo      E        32.77
# 13      Nintendo      E        22.70
# 15      Nintendo      E        21.80
# 77     EA Sports      E         8.58
# ...          ...    ...          ...
# 16680        NaN    NaN         0.00
# 16692    Mastiff      T         0.01
# 16697        NaN    NaN         0.01
# 16704        NaN    NaN         0.01
# 16715        NaN    NaN         0.01
#
# [2306 rows x 17 columns]

# %%
soccer= deportes[deportes['Name'].str.contains("FIFA|PES|Soccer")]
soccer
# Out:
#                                             Name Platform  Year_of_Release  \
# 77                                       FIFA 16      PS4           2015.0
# 94                                       FIFA 17      PS4           2016.0
# 122                                      FIFA 12      PS3           2011.0
# 126                                      FIFA 14      PS3           2013.0
# 143                                      FIFA 15      PS4           2014.0
# ...                                          ...      ...              ...
# 16035                             FIFA Soccer 08       PC           2007.0
# 16062              Worldwide Soccer Manager 2006       PC           2004.0
# 16178                               Fab 5 Soccer       DS           2008.0
# 16532                  Pro Evolution Soccer 2010       PC           2009.0
# 16555  Winning Eleven: Pro Evolution Soccer 2007       PC           2006.0
#
#         Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 77     Sports               Electronic Arts      1.12      6.12      0.06
# 94     Sports               Electronic Arts      0.66      5.75      0.08
# 122    Sports               Electronic Arts      0.84      4.30      0.11
# 126    Sports               Electronic Arts      0.78      4.24      0.07
# 143    Sports               Electronic Arts      0.80      4.33      0.05
# ...       ...                           ...       ...       ...       ...
# 16035  Sports               Electronic Arts      0.00      0.01      0.00
# 16062  Sports                          Sega      0.00      0.01      0.00
# 16178  Sports                     Destineer      0.01      0.00      0.00
# 16532  Sports  Konami Digital Entertainment      0.00      0.01      0.00
# 16555  Sports  Konami Digital Entertainment      0.00      0.01      0.00
#
#        Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# 77            1.28          8.57          82.0          42.0        4.3
# 94            1.11          7.59          85.0          41.0          5
# 122           1.39          6.65           NaN           NaN        NaN
# 126           1.37          6.47          86.0          37.0        4.3
# 143           0.90          6.08          82.0          47.0        5.7
# ...            ...           ...           ...           ...        ...
# 16035         0.00          0.02          77.0           7.0        6.1
# 16062         0.00          0.02          89.0          20.0        NaN
# 16178         0.00          0.01           NaN           NaN        tbd
# 16532         0.00          0.01          78.0           8.0        6.9
# 16555         0.00          0.01          88.0           6.0        NaN
#
#        User_Count                Developer Rating  total_sales
# 77          896.0                EA Sports      E         8.58
# 94          398.0  EA Sports, EA Vancouver      E         7.60
# 122           NaN                      NaN    NaN         6.64
# 126         576.0                EA Canada      E         6.46
# 143         988.0                EA Sports      E         6.08
# ...           ...                      ...    ...          ...
# 16035        50.0                EA Canada      E         0.01
# 16062         NaN       Sports Interactive      E         0.01
# 16178         NaN     Magellan Interactive      E         0.01
# 16532        49.0                   Konami      E         0.01
# 16555         NaN                     KCET      E         0.01
#
# [270 rows x 17 columns]

# %% [markdown]
# 270 ROWS!!!

# %%
game= soccer.groupby("Name")["Global_Sales"].sum().sort_values(ascending= False)
game
# Out:
# Name
# FIFA 15                          17.34
# FIFA 14                          16.48
# FIFA 16                          16.30
# FIFA 12                          13.06
# FIFA Soccer 11                   12.50
#                                  ...
# FIFA World Cup: Germany 2006      0.03
# Adidas Power Soccer 98            0.02
# Worldwide Soccer Manager 2006     0.02
# Worldwide Soccer Manager 2007     0.02
# Fab 5 Soccer                      0.01
# Name: Global_Sales, Length: 135, dtype: float64

# %%
game.head(10)
# Out:
# Name
# FIFA 15                      17.34
# FIFA 14                      16.48
# FIFA 16                      16.30
# FIFA 12                      13.06
# FIFA Soccer 11               12.50
# FIFA 17                      11.47
# FIFA Soccer 10               10.70
# FIFA Soccer 08                9.48
# FIFA Soccer 09                8.66
# Pro Evolution Soccer 2008     8.46
# Name: Global_Sales, dtype: float64

# %% [markdown]
# ## Fifa 15 Leads in Sales

# %%
game_platform= soccer.groupby(["Name", "Platform"])["Global_Sales"].sum().sort_values(ascending= False)
game_platform
# Out:
# Name                                       Platform
# FIFA 16                                    PS4         8.57
# FIFA 17                                    PS4         7.59
# FIFA 12                                    PS3         6.65
# FIFA 14                                    PS3         6.47
# FIFA 15                                    PS4         6.08
#                                                        ...
# Pro Evolution Soccer 2017                  PC          0.02
# FIFA Soccer 09                             PC          0.02
# Fab 5 Soccer                               DS          0.01
# Winning Eleven: Pro Evolution Soccer 2007  PC          0.01
# Pro Evolution Soccer 2010                  PC          0.01
# Name: Global_Sales, Length: 270, dtype: float64

# %%
game_platform.head(10)
# Out:
# Name                                       Platform
# FIFA 16                                    PS4         8.57
# FIFA 17                                    PS4         7.59
# FIFA 12                                    PS3         6.65
# FIFA 14                                    PS3         6.47
# FIFA 15                                    PS4         6.08
# FIFA Soccer 11                             PS3         5.07
# Winning Eleven: Pro Evolution Soccer 2007  PS2         4.39
# FIFA 15                                    PS3         4.28
# FIFA 14                                    X360        4.22
# FIFA Soccer 06                             PS2         4.21
# Name: Global_Sales, dtype: float64

# %% [markdown]
# ## But look at that! If you split platforms, FIFA 16 for PS4 is the one with highest Sales

# %%
game_critic= soccer.groupby(["Name", "Platform"])["Critic_Score"].sum().sort_values(ascending= False)

# %%
game_critic.head(10)
# Out:
# Name                                         Platform
# World Soccer Winning Eleven 6 International  PS2         93.0
# World Soccer Winning Eleven 7 International  PS2         93.0
# World Soccer Winning Eleven 8 International  PS2         91.0
# FIFA Soccer 10                               PS3         91.0
# World Soccer Winning Eleven 8 International  XB          90.0
# FIFA Soccer 10                               X360        90.0
# World Soccer Winning Eleven 9                XB          89.0
# FIFA Soccer 11                               PS3         89.0
# Worldwide Soccer Manager 2006                PC          89.0
# FIFA 14                                      XOne        88.0
# Name: Critic_Score, dtype: float64

# %%
game_critic.tail(10)
# Out:
# Name                                                Platform
# J-League Pro Soccer Club o Tsukurou! 6: Pride of J  PSP         0.0
# J-League Pro Soccer Club wo Tsukurou!               SAT         0.0
# LEGO Soccer Mania                                   GBA         0.0
# J-League Pro Soccer Club wo Tsukurou! 2             SAT         0.0
# J-League Soccer: Prime Goal                         SNES        0.0
# J-League Soccer: Prime Goal 2                       SNES        0.0
# J.League Pro Soccer Club o Tsukurou! 8 Euro Plus    PSP         0.0
# Jikkyou World Soccer 2000 Final Edition             PS2         0.0
# Jikkyou World Soccer 2002                           PS2         0.0
# Olympic Soccer: Atlanta 1996                        PS          0.0
# Name: Critic_Score, dtype: float64

# %%
# I want to see the lowest critics different to 0.
deportes_with_critic= df_con_resenaR.loc[df["Genre"]== "Sports"]
soccer_with_critic= deportes_with_critic[deportes_with_critic['Name'].str.contains("FIFA|PES|Soccer")]

# %%
soccer_with_critic.loc[soccer_with_critic["Critic_Score"]<=30]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year_of_Release, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales, Critic_Score, Critic_Count, User_Score, User_Count, Developer, Rating]
# Index: []

# %%
soccer
# Out:
#                                             Name Platform  Year_of_Release  \
# 77                                       FIFA 16      PS4           2015.0
# 94                                       FIFA 17      PS4           2016.0
# 122                                      FIFA 12      PS3           2011.0
# 126                                      FIFA 14      PS3           2013.0
# 143                                      FIFA 15      PS4           2014.0
# ...                                          ...      ...              ...
# 16035                             FIFA Soccer 08       PC           2007.0
# 16062              Worldwide Soccer Manager 2006       PC           2004.0
# 16178                               Fab 5 Soccer       DS           2008.0
# 16532                  Pro Evolution Soccer 2010       PC           2009.0
# 16555  Winning Eleven: Pro Evolution Soccer 2007       PC           2006.0
#
#         Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 77     Sports               Electronic Arts      1.12      6.12      0.06
# 94     Sports               Electronic Arts      0.66      5.75      0.08
# 122    Sports               Electronic Arts      0.84      4.30      0.11
# 126    Sports               Electronic Arts      0.78      4.24      0.07
# 143    Sports               Electronic Arts      0.80      4.33      0.05
# ...       ...                           ...       ...       ...       ...
# 16035  Sports               Electronic Arts      0.00      0.01      0.00
# 16062  Sports                          Sega      0.00      0.01      0.00
# 16178  Sports                     Destineer      0.01      0.00      0.00
# 16532  Sports  Konami Digital Entertainment      0.00      0.01      0.00
# 16555  Sports  Konami Digital Entertainment      0.00      0.01      0.00
#
#        Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# 77            1.28          8.57          82.0          42.0        4.3
# 94            1.11          7.59          85.0          41.0          5
# 122           1.39          6.65           NaN           NaN        NaN
# 126           1.37          6.47          86.0          37.0        4.3
# 143           0.90          6.08          82.0          47.0        5.7
# ...            ...           ...           ...           ...        ...
# 16035         0.00          0.02          77.0           7.0        6.1
# 16062         0.00          0.02          89.0          20.0        NaN
# 16178         0.00          0.01           NaN           NaN        tbd
# 16532         0.00          0.01          78.0           8.0        6.9
# 16555         0.00          0.01          88.0           6.0        NaN
#
#        User_Count                Developer Rating  total_sales
# 77          896.0                EA Sports      E         8.58
# 94          398.0  EA Sports, EA Vancouver      E         7.60
# 122           NaN                      NaN    NaN         6.64
# 126         576.0                EA Canada      E         6.46
# 143         988.0                EA Sports      E         6.08
# ...           ...                      ...    ...          ...
# 16035        50.0                EA Canada      E         0.01
# 16062         NaN       Sports Interactive      E         0.01
# 16178         NaN     Magellan Interactive      E         0.01
# 16532        49.0                   Konami      E         0.01
# 16555         NaN                     KCET      E         0.01
#
# [270 rows x 17 columns]

# %%
soccer_TOP= soccer.loc[(soccer["Name"]== "FIFA 15")| (soccer["Name"]== "FIFA 16")| (soccer["Name"]== "FIFA 17")|
                      (soccer["Name"]== "Winning Eleven: Pro Evolution Soccer 2007")|  (soccer["Name"]== "FIFA Soccer 06")]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
soccer_TOP
# Out:
#                                             Name Platform  Year_of_Release  \
# 77                                       FIFA 16      PS4           2015.0
# 94                                       FIFA 17      PS4           2016.0
# 143                                      FIFA 15      PS4           2014.0
# 250    Winning Eleven: Pro Evolution Soccer 2007      PS2           2006.0
# 264                                      FIFA 15      PS3           2014.0
# 274                               FIFA Soccer 06      PS2           2005.0
# 417                                      FIFA 16     XOne           2015.0
# 494                                      FIFA 15     X360           2014.0
# 552                                      FIFA 16      PS3           2015.0
# 571                                      FIFA 17     XOne           2016.0
# 754                                      FIFA 15     XOne           2014.0
# 1182                                     FIFA 16     X360           2015.0
# 2418   Winning Eleven: Pro Evolution Soccer 2007      PSP           2006.0
# 2782                                     FIFA 17      PS3           2016.0
# 2987                              FIFA Soccer 06       XB           2005.0
# 3381                                     FIFA 15      PSV           2014.0
# 3611                                     FIFA 15      Wii           2014.0
# 4279                                     FIFA 15      3DS           2014.0
# 5010                                     FIFA 17     X360           2016.0
# 6098                                     FIFA 15       PC           2014.0
# 7576                                     FIFA 16       PC           2015.0
# 8217   Winning Eleven: Pro Evolution Soccer 2007       DS           2006.0
# 9956                                     FIFA 17       PC           2016.0
# 10151                             FIFA Soccer 06      PSP           2005.0
# 10450  Winning Eleven: Pro Evolution Soccer 2007     X360           2006.0
# 12183                             FIFA Soccer 06      GBA           2005.0
# 12802                             FIFA Soccer 06       DS           2005.0
# 16555  Winning Eleven: Pro Evolution Soccer 2007       PC           2006.0
#
#         Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 77     Sports               Electronic Arts      1.12      6.12      0.06
# 94     Sports               Electronic Arts      0.66      5.75      0.08
# 143    Sports               Electronic Arts      0.80      4.33      0.05
# 250    Sports  Konami Digital Entertainment      0.10      2.39      1.05
# 264    Sports               Electronic Arts      0.58      3.02      0.04
# 274    Sports               Electronic Arts      0.78      2.55      0.04
# 417    Sports               Electronic Arts      0.89      2.12      0.00
# 494    Sports               Electronic Arts      0.79      1.92      0.00
# 552    Sports               Electronic Arts      0.41      1.84      0.05
# 571    Sports               Electronic Arts      0.43      2.05      0.00
# 754    Sports               Electronic Arts      0.60      1.42      0.00
# 1182   Sports               Electronic Arts      0.57      0.88      0.00
# 2418   Sports  Konami Digital Entertainment      0.01      0.72      0.12
# 2782   Sports               Electronic Arts      0.05      0.55      0.03
# 2987   Sports               Electronic Arts      0.29      0.38      0.00
# 3381   Sports               Electronic Arts      0.08      0.35      0.05
# 3611   Sports               Electronic Arts      0.15      0.37      0.00
# 4279   Sports               Electronic Arts      0.09      0.34      0.00
# 5010   Sports               Electronic Arts      0.07      0.28      0.00
# 6098   Sports               Electronic Arts      0.00      0.27      0.00
# 7576   Sports               Electronic Arts      0.06      0.13      0.00
# 8217   Sports  Konami Digital Entertainment      0.00      0.00      0.17
# 9956   Sports               Electronic Arts      0.00      0.11      0.00
# 10151  Sports               Electronic Arts      0.10      0.00      0.00
# 10450  Sports  Konami Digital Entertainment      0.09      0.00      0.00
# 12183  Sports               Electronic Arts      0.05      0.02      0.00
# 12802  Sports               Electronic Arts      0.05      0.00      0.00
# 16555  Sports  Konami Digital Entertainment      0.00      0.01      0.00
#
#        Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# 77            1.28          8.57          82.0          42.0        4.3
# 94            1.11          7.59          85.0          41.0          5
# 143           0.90          6.08          82.0          47.0        5.7
# 250           0.86          4.39          86.0          19.0        8.9
# 264           0.64          4.28           NaN           NaN        4.5
# 274           0.84          4.21          80.0          32.0        7.8
# 417           0.24          3.25          84.0          45.0        4.4
# 494           0.21          2.92           NaN           NaN        4.2
# 552           0.40          2.71           NaN           NaN        3.2
# 571           0.17          2.65          84.0          50.0        5.5
# 754           0.16          2.18          82.0          33.0        5.4
# 1182          0.12          1.57           NaN           NaN        2.9
# 2418          0.01          0.86          81.0          10.0        8.3
# 2782          0.10          0.73           NaN           NaN        3.3
# 2987          0.01          0.68          80.0          39.0        7.5
# 3381          0.12          0.59           NaN           NaN        3.1
# 3611          0.04          0.56           NaN           NaN        4.3
# 4279          0.03          0.45           NaN           NaN        2.4
# 5010          0.03          0.38           NaN           NaN        1.7
# 6098          0.02          0.28          82.0           9.0        4.2
# 7576          0.01          0.20          81.0          10.0        4.4
# 8217          0.00          0.17          63.0           5.0        7.9
# 9956          0.01          0.12          84.0          12.0        4.2
# 10151         0.01          0.11          77.0          17.0        7.7
# 10450         0.01          0.10          79.0          22.0        6.5
# 12183         0.00          0.07           NaN           NaN        tbd
# 12802         0.00          0.06           NaN           NaN        NaN
# 16555         0.00          0.01          88.0           6.0        NaN
#
#        User_Count                Developer Rating  total_sales
# 77          896.0                EA Sports      E         8.58
# 94          398.0  EA Sports, EA Vancouver      E         7.60
# 143         988.0                EA Sports      E         6.08
# 250          33.0                   Konami      E         4.40
# 264         109.0                EA Sports      E         4.28
# 274          47.0                EA Canada      E         4.21
# 417         459.0                EA Sports      E         3.25
# 494          85.0                EA Sports      E         2.92
# 552          58.0                EA Sports      E         2.70
# 571         201.0  EA Sports, EA Vancouver      E         2.65
# 754         347.0                EA Sports      E         2.18
# 1182         45.0                EA Sports      E         1.57
# 2418         14.0                     KCET      E         0.86
# 2782         21.0  EA Sports, EA Vancouver      E         0.73
# 2987         22.0                EA Canada      E         0.68
# 3381         42.0                EA Sports      E         0.60
# 3611         12.0                EA Sports      E         0.56
# 4279         35.0                EA Sports      E         0.46
# 5010         23.0  EA Sports, EA Vancouver      E         0.38
# 6098        383.0                EA Sports      E         0.29
# 7576        296.0                EA Sports      E         0.20
# 8217         12.0                     KCET      E         0.17
# 9956        160.0  EA Sports, EA Vancouver      E         0.12
# 10151        20.0                EA Sports      E         0.11
# 10450        33.0                     KCET      E         0.10
# 12183         NaN          Electronic Arts      E         0.07
# 12802         NaN                      NaN    NaN         0.05
# 16555         NaN                     KCET      E         0.01

# %%
soccer_TOP_group= soccer_TOP.groupby(["Name", "Platform"])["JP_Sales", "NA_Sales", "EU_Sales", "Other_Sales"].sum().sort_values(by= "Name", ascending= True)

# %%
soccer_TOP_group
# Out:
#                                                     JP_Sales  NA_Sales  \
# Name                                      Platform
# FIFA 15                                   3DS           0.00      0.09
#                                           PC            0.00      0.00
#                                           PS3           0.04      0.58
#                                           PS4           0.05      0.80
#                                           PSV           0.05      0.08
#                                           Wii           0.00      0.15
#                                           X360          0.00      0.79
#                                           XOne          0.00      0.60
# FIFA 16                                   PC            0.00      0.06
#                                           PS3           0.05      0.41
#                                           PS4           0.06      1.12
#                                           X360          0.00      0.57
#                                           XOne          0.00      0.89
# FIFA 17                                   XOne          0.00      0.43
#                                           X360          0.00      0.07
#                                           PC            0.00      0.00
#                                           PS3           0.03      0.05
#                                           PS4           0.08      0.66
# FIFA Soccer 06                            DS            0.00      0.05
#                                           GBA           0.00      0.05
#                                           PS2           0.04      0.78
#                                           PSP           0.00      0.10
#                                           XB            0.00      0.29
# Winning Eleven: Pro Evolution Soccer 2007 PSP           0.12      0.01
#                                           DS            0.17      0.00
#                                           PC            0.00      0.00
#                                           PS2           1.05      0.10
#                                           X360          0.00      0.09
#
#                                                     EU_Sales  Other_Sales
# Name                                      Platform
# FIFA 15                                   3DS           0.34         0.03
#                                           PC            0.27         0.02
#                                           PS3           3.02         0.64
#                                           PS4           4.33         0.90
#                                           PSV           0.35         0.12
#                                           Wii           0.37         0.04
#                                           X360          1.92         0.21
#                                           XOne          1.42         0.16
# FIFA 16                                   PC            0.13         0.01
#                                           PS3           1.84         0.40
#                                           PS4           6.12         1.28
#                                           X360          0.88         0.12
#                                           XOne          2.12         0.24
# FIFA 17                                   XOne          2.05         0.17
#                                           X360          0.28         0.03
#                                           PC            0.11         0.01
#                                           PS3           0.55         0.10
#                                           PS4           5.75         1.11
# FIFA Soccer 06                            DS            0.00         0.00
#                                           GBA           0.02         0.00
#                                           PS2           2.55         0.84
#                                           PSP           0.00         0.01
#                                           XB            0.38         0.01
# Winning Eleven: Pro Evolution Soccer 2007 PSP           0.72         0.01
#                                           DS            0.00         0.00
#                                           PC            0.01         0.00
#                                           PS2           2.39         0.86
#                                           X360          0.00         0.01

# %%
soccer_TOP_group.reset_index()
# Out:
#                                          Name Platform  JP_Sales  NA_Sales  \
# 0                                     FIFA 15      3DS      0.00      0.09
# 1                                     FIFA 15       PC      0.00      0.00
# 2                                     FIFA 15      PS3      0.04      0.58
# 3                                     FIFA 15      PS4      0.05      0.80
# 4                                     FIFA 15      PSV      0.05      0.08
# 5                                     FIFA 15      Wii      0.00      0.15
# 6                                     FIFA 15     X360      0.00      0.79
# 7                                     FIFA 15     XOne      0.00      0.60
# 8                                     FIFA 16       PC      0.00      0.06
# 9                                     FIFA 16      PS3      0.05      0.41
# 10                                    FIFA 16      PS4      0.06      1.12
# 11                                    FIFA 16     X360      0.00      0.57
# 12                                    FIFA 16     XOne      0.00      0.89
# 13                                    FIFA 17     XOne      0.00      0.43
# 14                                    FIFA 17     X360      0.00      0.07
# 15                                    FIFA 17       PC      0.00      0.00
# 16                                    FIFA 17      PS3      0.03      0.05
# 17                                    FIFA 17      PS4      0.08      0.66
# 18                             FIFA Soccer 06       DS      0.00      0.05
# 19                             FIFA Soccer 06      GBA      0.00      0.05
# 20                             FIFA Soccer 06      PS2      0.04      0.78
# 21                             FIFA Soccer 06      PSP      0.00      0.10
# 22                             FIFA Soccer 06       XB      0.00      0.29
# 23  Winning Eleven: Pro Evolution Soccer 2007      PSP      0.12      0.01
# 24  Winning Eleven: Pro Evolution Soccer 2007       DS      0.17      0.00
# 25  Winning Eleven: Pro Evolution Soccer 2007       PC      0.00      0.00
# 26  Winning Eleven: Pro Evolution Soccer 2007      PS2      1.05      0.10
# 27  Winning Eleven: Pro Evolution Soccer 2007     X360      0.00      0.09
#
#     EU_Sales  Other_Sales
# 0       0.34         0.03
# 1       0.27         0.02
# 2       3.02         0.64
# 3       4.33         0.90
# 4       0.35         0.12
# 5       0.37         0.04
# 6       1.92         0.21
# 7       1.42         0.16
# 8       0.13         0.01
# 9       1.84         0.40
# 10      6.12         1.28
# 11      0.88         0.12
# 12      2.12         0.24
# 13      2.05         0.17
# 14      0.28         0.03
# 15      0.11         0.01
# 16      0.55         0.10
# 17      5.75         1.11
# 18      0.00         0.00
# 19      0.02         0.00
# 20      2.55         0.84
# 21      0.00         0.01
# 22      0.38         0.01
# 23      0.72         0.01
# 24      0.00         0.00
# 25      0.01         0.00
# 26      2.39         0.86
# 27      0.00         0.01

# %%
soccer_sales= soccer_TOP.groupby(["Name"])["JP_Sales", "NA_Sales", "EU_Sales", "Other_Sales"].sum().sort_values(by= "Name", ascending= True)

# %%
soccer_sales.reset_index()
# Out:
#                                         Name  JP_Sales  NA_Sales  EU_Sales  \
# 0                                    FIFA 15      0.14      3.09     12.02
# 1                                    FIFA 16      0.11      3.05     11.09
# 2                                    FIFA 17      0.11      1.21      8.74
# 3                             FIFA Soccer 06      0.04      1.27      2.95
# 4  Winning Eleven: Pro Evolution Soccer 2007      1.34      0.20      3.12
#
#    Other_Sales
# 0         2.12
# 1         2.05
# 2         1.42
# 3         0.86
# 4         0.88

# %% [markdown]
# We can see how Winning Eleven was the king in JAPAN and in North America it sold very little.

# %% [markdown]
# FIFA 15 and 16 really got into NA and EU being above the competition

# %%
top_games= ['FIFA 15',
  'FIFA 16',
  'FIFA 17',
  'Winning Eleven: Pro Evolution Soccer 2007',
  'FIFA Soccer 06']

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="Name", y="JP_Sales", hue= "Platform", data=soccer_TOP)
ax.set_title("Sales in JAPAN for Top Games")
plt.show()

# %%
# This graph is not good to show what we wanna show.

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
ax = sns.barplot(x=soccer_sales.index, y="JP_Sales", data=soccer_sales, palette="autumn")
ax.set_title("Sales in JAPAN for Top Games")
plt.show()

# %%
ax = sns.barplot(x=soccer_sales.index, y="NA_Sales", data=soccer_sales, palette="autumn")
ax.set_title("Sales in North America for Top Games")
plt.show()

# %%
ax = sns.barplot(x=soccer_sales.index, y="EU_Sales", data=soccer_sales, palette="autumn")
ax.set_title("Sales in Europe for Top Games")
plt.show()

# %%
ax = sns.barplot(x=soccer_sales.index, y="Other_Sales", data=soccer_sales, palette="autumn")
ax.set_title("Sales in Rest of the World for Top Games")
plt.show()

# %%
soccer_sales.index
# Out:
# Index(['FIFA 15', 'FIFA 16', 'FIFA 17', 'FIFA Soccer 06',
#        'Winning Eleven: Pro Evolution Soccer 2007'],
#       dtype='object', name='Name')
